# %%
# !pip install praat-textgrids
# Out:
# Collecting praat-textgrids
#   Using cached praat_textgrids-1.4.0-py3-none-any.whl (25 kB)
# WARNING: Error parsing requirements for jupyter-highlight-selected-word: [Errno 2] No such file or directory: '/home/co/miniconda3/envs/meg/lib/python3.9/site-packages/jupyter_highlight_selected_word-0.2.0.dist-info/METADATA'
# WARNING: Error parsing requirements for jupyter-contrib-nbextensions: [Errno 2] No such file or directory: '/home/co/miniconda3/envs/meg/lib/python3.9/site-packages/jupyter_contrib_nbextensions-0.5.1.dist-info/METADATA'
# Installing collected packages: praat-textgrids
# Successfully installed praat-textgrids-1.4.0

# %%
import pandas as pd
import textgrids
import mne
import mne_bids

# %%
# Load the text grid

grid = textgrids.TextGrid('./stimuli/grid/text_french_run1.TextGrid')
grid
# Out:
# File type = "ooTextFile"
# Object class = "TextGrid"
#
# xmin = 0.0
# xmax = 612.591814
# tiers? <exists>
# size = 3
# item []:
#     item [1]:
#         class = "IntervalTier"
#         name = "ORT-MAU"
#         xmin = 0.0
#         xmax = 612.591814
#         intervals: size = 1756
#             intervals [1]:
#                 xmin = 0.0
#                 xmax = 2.08712
#                 text = ""
#             intervals [2]:
#                 xmin = 2.08712
#                 xmax = 2.52712
#                 text = "lorsque"
#             intervals [3]:
#                 xmin = 2.52712
#                 xmax = 2.99712
#                 text = "j'avais"
#             intervals [4]:
#                 xmin = 2.99712
#                 xmax = 3.25712
#                 text = "six"
#             intervals [5]:
#                 xmin = 3.25712
#                 xmax = 3.52712
#                 text = "ans"
#             intervals [6]:
#                 xmin = 3.52712
#                 xmax = 4.10712
#                 text = "j'ai"
#             intervals [7]:
#                 xmin = 4.10712
#                 xmax = 4.31712
#                 text = ""
#             intervals [8]:
#                 xmin = 4.31712
#                 xmax = 4.39712
#                 text = "vu"
#             intervals [9]:
#                 xmin = 4.39712
#                 xmax = 4.58712
#                 text = "une"
#             intervals [10]:
#                 xmin = 4.58712
#                 xmax = 4.67712
#                 text = ""
#             intervals [11]:
#                 xmin = 4.67712
#                 xmax = 4.92712
#                 text = "fois"
#             intervals [12]:
#                 xmin = 4.92712
#                 xmax = 5.19712
#                 text = ""
#             intervals [13]:
#                 xmin = 5.19712
#                 xmax = 5.51712
#                 text = "une"
#             intervals [14]:
#                 xmin = 5.51712
#                 xmax = 6.40712
#                 text = "magnifique"
#             intervals [15]:
#                 xmin = 6.40712
#                 xmax = 6.77712
#                 text = "image"
#             intervals [16]:
#                 xmin = 6.77712
#                 xmax = 6.95712
#                 text = ""
#             intervals [17]:
#                 xmin = 6.95712
#                 xmax = 7.09712
#                 text = "dans"
#             intervals [18]:
#                 xmin = 7.09712
#                 xmax = 7.23712
#                 text = "un"
#             intervals [19]:
#                 xmin = 7.23712
#                 xmax = 7.60712
#                 text = "livre"
#             intervals [20]:
#                 xmin = 7.60712
#                 xmax = 7.79712
#                 text = "sur"
#             intervals [21]:
#                 xmin = 7.79712
#                 xmax = 8.06712
#                 text = "la"
#             intervals [22]:
#                 xmin = 8.06712
#                 xmax = 8.43712
#                 text = "forêt"
#             intervals [23]:
#                 xmin = 8.43712
#                 xmax = 8.87712
#                 text = "vierge"
#             intervals [24]:
#                 xmin = 8.87712
#                 xmax = 9.07712
#                 text = "qui"
#             intervals [25]:
#                 xmin = 9.07712
#                 xmax = 9.72712
#                 text = "s'appelait"
#             intervals [26]:
#                 xmin = 9.72712
#                 xmax = 9.90712
#                 text = ""
#             intervals [27]:
#                 xmin = 9.90712
#                 xmax = 10.43712
#                 text = "histoires"
#             intervals [28]:
#                 xmin = 10.43712
#                 xmax = 10.85712
#                 text = "vécues"
#             intervals [29]:
#                 xmin = 10.85712
#                 xmax = 11.81712
#                 text = ""
#             intervals [30]:
#                 xmin = 11.81712
#                 xmax = 11.92712
#                 text = "ça"
#             intervals [31]:
#                 xmin = 11.92712
#                 xmax = 12.62712
#                 text = "représentait"
#             intervals [32]:
#                 xmin = 12.62712
#                 xmax = 12.76712
#                 text = "un"
#             intervals [33]:
#                 xmin = 12.76712
#                 xmax = 13.27712
#                 text = "serpent"
#             intervals [34]:
#                 xmin = 13.27712
#                 xmax = 13.60712
#                 text = "boa"
#             intervals [35]:
#                 xmin = 13.60712
#                 xmax = 13.81712
#                 text = ""
#             intervals [36]:
#                 xmin = 13.81712
#                 xmax = 14.05712
#                 text = "qui"
#             intervals [37]:
#                 xmin = 14.05712
#                 xmax = 14.50712
#                 text = "avalait"
#             intervals [38]:
#                 xmin = 14.50712
#                 xmax = 14.66712
#                 text = "un"
#             intervals [39]:
#                 xmin = 14.66712
#                 xmax = 15.21712
#                 text = "fauve"
#             intervals [40]:
#                 xmin = 15.21712
#                 xmax = 15.83712
#                 text = ""
#             intervals [41]:
#                 xmin = 15.83712
#                 xmax = 16.20712
#                 text = "voilà"
#             intervals [42]:
#                 xmin = 16.20712
#                 xmax = 16.32712
#                 text = "la"
#             intervals [43]:
#                 xmin = 16.32712
#                 xmax = 16.71712
#                 text = "copie"
#             intervals [44]:
#                 xmin = 16.71712
#                 xmax = 16.87712
#                 text = "du"
#             intervals [45]:
#                 xmin = 16.87712
#                 xmax = 17.25712
#                 text = "dessin"
#             intervals [46]:
#                 xmin = 17.25712
#                 xmax = 18.51712
#                 text = ""
#             intervals [47]:
#                 xmin = 18.51712
#                 xmax = 18.70712
#                 text = "on"
#             intervals [48]:
#                 xmin = 18.70712
#                 xmax = 19.03712
#                 text = "disait"
#             intervals [49]:
#                 xmin = 19.03712
#                 xmax = 19.16712
#                 text = "dans"
#             intervals [50]:
#                 xmin = 19.16712
#                 xmax = 19.60712
#                 text = "le"
#             intervals [51]:
#                 xmin = 19.60712
#                 xmax = 19.87712
#                 text = "livre"
#             intervals [52]:
#                 xmin = 19.87712
#                 xmax = 20.05712
#                 text = ""
#             intervals [53]:
#                 xmin = 20.05712
#                 xmax = 20.31712
#                 text = "les"
#             intervals [54]:
#                 xmin = 20.31712
#                 xmax = 20.75712
#                 text = "serpents"
#             intervals [55]:
#                 xmin = 20.75712
#                 xmax = 21.07712
#                 text = "boas"
#             intervals [56]:
#                 xmin = 21.07712
#                 xmax = 21.74712
#                 text = "avalent"
#             intervals [57]:
#                 xmin = 21.74712
#                 xmax = 21.91712
#                 text = "leur"
#             intervals [58]:
#                 xmin = 21.91712
#                 xmax = 22.31712
#                 text = "proie"
#             intervals [59]:
#                 xmin = 22.31712
#                 xmax = 22.46712
#                 text = ""
#             intervals [60]:
#                 xmin = 22.46712
#                 xmax = 22.73712
#                 text = "tout"
#             intervals [61]:
#                 xmin = 22.73712
#                 xmax = 23.242109
#                 text = "entière"
#             intervals [62]:
#                 xmin = 23.242109
#                 xmax = 23.56712
#                 text = "sans"
#             intervals [63]:
#                 xmin = 23.56712
#                 xmax = 23.66712
#                 text = "la"
#             intervals [64]:
#                 xmin = 23.66712
#                 xmax = 23.91712
#                 text = "mâcher"
#             intervals [65]:
#                 xmin = 23.91712
#                 xmax = 24.38712
#                 text = "ensuite"
#             intervals [66]:
#                 xmin = 24.38712
#                 xmax = 24.76712
#                 text = ""
#             intervals [67]:
#                 xmin = 24.76712
#                 xmax = 25.16712
#                 text = "ils"
#             intervals [68]:
#                 xmin = 25.16712
#                 xmax = 25.31712
#                 text = "ne"
#             intervals [69]:
#                 xmin = 25.31712
#                 xmax = 25.63712
#                 text = "peuvent"
#             intervals [70]:
#                 xmin = 25.63712
#                 xmax = 25.82712
#                 text = "plus"
#             intervals [71]:
#                 xmin = 25.82712
#                 xmax = 25.92712
#                 text = ""
#             intervals [72]:
#                 xmin = 25.92712
#                 xmax = 26.38712
#                 text = "bouger"
#             intervals [73]:
#                 xmin = 26.38712
#                 xmax = 26.59712
#                 text = "et"
#             intervals [74]:
#                 xmin = 26.59712
#                 xmax = 26.73712
#                 text = ""
#             intervals [75]:
#                 xmin = 26.73712
#                 xmax = 27.07712
#                 text = "ils"
#             intervals [76]:
#                 xmin = 27.07712
#                 xmax = 27.55712
#                 text = "dorment"
#             intervals [77]:
#                 xmin = 27.55712
#                 xmax = 27.87712
#                 text = "pendant"
#             intervals [78]:
#                 xmin = 27.87712
#                 xmax = 28.15712
#                 text = "les"
#             intervals [79]:
#                 xmin = 28.15712
#                 xmax = 28.33712
#                 text = "six"
#             intervals [80]:
#                 xmin = 28.33712
#                 xmax = 28.58712
#                 text = "mois"
#             intervals [81]:
#                 xmin = 28.58712
#                 xmax = 28.76712
#                 text = "de"
#             intervals [82]:
#                 xmin = 28.76712
#                 xmax = 28.87712
#                 text = "leur"
#             intervals [83]:
#                 xmin = 28.87712
#                 xmax = 29.50712
#                 text = "digestion"
#             intervals [84]:
#                 xmin = 29.50712
#                 xmax = 31.25712
#                 text = ""
#             intervals [85]:
#                 xmin = 31.25712
#                 xmax = 31.43712
#                 text = "j'ai"
#             intervals [86]:
#                 xmin = 31.43712
#                 xmax = 31.84712
#                 text = "alors"
#             intervals [87]:
#                 xmin = 31.84712
#                 xmax = 32.53712
#                 text = "beaucoup"
#             intervals [88]:
#                 xmin = 32.53712
#                 xmax = 33.16712
#                 text = "réfléchi"
#             intervals [89]:
#                 xmin = 33.16712
#                 xmax = 33.48712
#                 text = "sur"
#             intervals [90]:
#                 xmin = 33.48712
#                 xmax = 33.64712
#                 text = "les"
#             intervals [91]:
#                 xmin = 33.64712
#                 xmax = 34.04712
#                 text = "aventures"
#             intervals [92]:
#                 xmin = 34.04712
#                 xmax = 34.22712
#                 text = "de"
#             intervals [93]:
#                 xmin = 34.22712
#                 xmax = 34.32712
#                 text = "la"
#             intervals [94]:
#                 xmin = 34.32712
#                 xmax = 34.81712
#                 text = "jungle"
#             intervals [95]:
#                 xmin = 34.81712
#                 xmax = 35.19712
#                 text = ""
#             intervals [96]:
#                 xmin = 35.19712
#                 xmax = 35.50712
#                 text = "et"
#             intervals [97]:
#                 xmin = 35.50712
#                 xmax = 35.58712
#                 text = ""
#             intervals [98]:
#                 xmin = 35.58712
#                 xmax = 35.79712
#                 text = "à"
#             intervals [99]:
#                 xmin = 35.79712
#                 xmax = 35.99712
#                 text = "mon"
#             intervals [100]:
#                 xmin = 35.99712
#                 xmax = 36.34712
#                 text = "tour"
#             intervals [101]:
#                 xmin = 36.34712
#                 xmax = 36.54712
#                 text = ""
#             intervals [102]:
#                 xmin = 36.54712
#                 xmax = 36.77712
#                 text = "j'ai"
#             intervals [103]:
#                 xmin = 36.77712
#                 xmax = 37.37712
#                 text = "réussi"
#             intervals [104]:
#                 xmin = 37.37712
#                 xmax = 37.54712
#                 text = ""
#             intervals [105]:
#                 xmin = 37.54712
#                 xmax = 37.91712
#                 text = "avec"
#             intervals [106]:
#                 xmin = 37.91712
#                 xmax = 38.03712
#                 text = "un"
#             intervals [107]:
#                 xmin = 38.03712
#                 xmax = 38.40712
#                 text = "crayon"
#             intervals [108]:
#                 xmin = 38.40712
#                 xmax = 38.51712
#                 text = "de"
#             intervals [109]:
#                 xmin = 38.51712
#                 xmax = 39.14712
#                 text = "couleur"
#             intervals [110]:
#                 xmin = 39.14712
#                 xmax = 39.51712
#                 text = ""
#             intervals [111]:
#                 xmin = 39.51712
#                 xmax = 39.68712
#                 text = "à"
#             intervals [112]:
#                 xmin = 39.68712
#                 xmax = 40.22712
#                 text = "tracer"
#             intervals [113]:
#                 xmin = 40.22712
#                 xmax = 40.43712
#                 text = "mon"
#             intervals [114]:
#                 xmin = 40.43712
#                 xmax = 40.92712
#                 text = "premier"
#             intervals [115]:
#                 xmin = 40.92712
#                 xmax = 41.30712
#                 text = "dessin"
#             intervals [116]:
#                 xmin = 41.30712
#                 xmax = 41.88712
#                 text = ""
#             intervals [117]:
#                 xmin = 41.88712
#                 xmax = 42.10712
#                 text = "mon"
#             intervals [118]:
#                 xmin = 42.10712
#                 xmax = 42.52712
#                 text = "dessin"
#             intervals [119]:
#                 xmin = 42.52712
#                 xmax = 43.01712
#                 text = "numéro"
#             intervals [120]:
#                 xmin = 43.01712
#                 xmax = 43.23712
#                 text = "eins"
#             intervals [121]:
#                 xmin = 43.23712
#                 xmax = 43.96712
#                 text = ""
#             intervals [122]:
#                 xmin = 43.96712
#                 xmax = 44.14712
#                 text = "il"
#             intervals [123]:
#                 xmin = 44.14712
#                 xmax = 44.46712
#                 text = "était"
#             intervals [124]:
#                 xmin = 44.46712
#                 xmax = 44.80712
#                 text = "comme"
#             intervals [125]:
#                 xmin = 44.80712
#                 xmax = 45.06712
#                 text = "ça"
#             intervals [126]:
#                 xmin = 45.06712
#                 xmax = 46.61712
#                 text = ""
#             intervals [127]:
#                 xmin = 46.61712
#                 xmax = 46.75712
#                 text = "j'ai"
#             intervals [128]:
#                 xmin = 46.75712
#                 xmax = 47.16712
#                 text = "montré"
#             intervals [129]:
#                 xmin = 47.16712
#                 xmax = 47.29712
#                 text = "mon"
#             intervals [130]:
#                 xmin = 47.29712
#                 xmax = 47.93712
#                 text = "chef-d-'-oeuvre"
#             intervals [131]:
#                 xmin = 47.93712
#                 xmax = 48.19712
#                 text = "aux"
#             intervals [132]:
#                 xmin = 48.19712
#                 xmax = 48.42712
#                 text = "grandes"
#             intervals [133]:
#                 xmin = 48.42712
#                 xmax = 49.04712
#                 text = "personnes"
#             intervals [134]:
#                 xmin = 49.04712
#                 xmax = 49.10712
#                 text = "et"
#             intervals [135]:
#                 xmin = 49.10712
#                 xmax = 49.34712
#                 text = ""
#             intervals [136]:
#                 xmin = 49.34712
#                 xmax = 49.60712
#                 text = "je"
#             intervals [137]:
#                 xmin = 49.60712
#                 xmax = 49.81712
#                 text = "leur"
#             intervals [138]:
#                 xmin = 49.81712
#                 xmax = 49.90712
#                 text = "ai"
#             intervals [139]:
#                 xmin = 49.90712
#                 xmax = 50.31712
#                 text = "demandé"
#             intervals [140]:
#                 xmin = 50.31712
#                 xmax = 50.51712
#                 text = "si"
#             intervals [141]:
#                 xmin = 50.51712
#                 xmax = 50.66712
#                 text = "mon"
#             intervals [142]:
#                 xmin = 50.66712
#                 xmax = 50.99712
#                 text = "dessin"
#             intervals [143]:
#                 xmin = 50.99712
#                 xmax = 51.18712
#                 text = "leur"
#             intervals [144]:
#                 xmin = 51.18712
#                 xmax = 51.56712
#                 text = "faisait"
#             intervals [145]:
#                 xmin = 51.56712
#                 xmax = 52.01712
#                 text = "peur"
#             intervals [146]:
#                 xmin = 52.01712
#                 xmax = 53.37712
#                 text = ""
#             intervals [147]:
#                 xmin = 53.37712
#                 xmax = 53.57712
#                 text = "elles"
#             intervals [148]:
#                 xmin = 53.57712
#                 xmax = 53.93712
#                 text = "m'ont"
#             intervals [149]:
#                 xmin = 53.93712
#                 xmax = 54.39712
#                 text = "répondu"
#             intervals [150]:
#                 xmin = 54.39712
#                 xmax = 54.87712
#                 text = ""
#             intervals [151]:
#                 xmin = 54.87712
#                 xmax = 55.37712
#                 text = "pourquoi"
#             intervals [152]:
#                 xmin = 55.37712
#                 xmax = 55.54712
#                 text = "un"
#             intervals [153]:
#                 xmin = 55.54712
#                 xmax = 55.92712
#                 text = "chapeau"
#             intervals [154]:
#                 xmin = 55.92712
#                 xmax = 56.71712
#                 text = "ferait-il"
#             intervals [155]:
#                 xmin = 56.71712
#                 xmax = 57.48712
#                 text = ""
#             intervals [156]:
#                 xmin = 57.48712
#                 xmax = 57.58712
#                 text = "peur"
#             intervals [157]:
#                 xmin = 57.58712
#                 xmax = 57.86712
#                 text = ""
#             intervals [158]:
#                 xmin = 57.86712
#                 xmax = 58.07712
#                 text = "mon"
#             intervals [159]:
#                 xmin = 58.07712
#                 xmax = 58.44712
#                 text = "dessin"
#             intervals [160]:
#                 xmin = 58.44712
#                 xmax = 58.50712
#                 text = "ne"
#             intervals [161]:
#                 xmin = 58.50712
#                 xmax = 59.36712
#                 text = "représentait"
#             intervals [162]:
#                 xmin = 59.36712
#                 xmax = 59.63712
#                 text = "pas"
#             intervals [163]:
#                 xmin = 59.63712
#                 xmax = 59.66712
#                 text = "un"
#             intervals [164]:
#                 xmin = 59.66712
#                 xmax = 59.92712
#                 text = "chapeau"
#             intervals [165]:
#                 xmin = 59.92712
#                 xmax = 60.31712
#                 text = ""
#             intervals [166]:
#                 xmin = 60.31712
#                 xmax = 60.58712
#                 text = "il"
#             intervals [167]:
#                 xmin = 60.58712
#                 xmax = 61.23712
#                 text = "représentait"
#             intervals [168]:
#                 xmin = 61.23712
#                 xmax = 61.34712
#                 text = "un"
#             intervals [169]:
#                 xmin = 61.34712
#                 xmax = 61.79712
#                 text = "serpent"
#             intervals [170]:
#                 xmin = 61.79712
#                 xmax = 62.16712
#                 text = "boa"
#             intervals [171]:
#                 xmin = 62.16712
#                 xmax = 62.42712
#                 text = "qui"
#             intervals [172]:
#                 xmin = 62.42712
#                 xmax = 63.03712
#                 text = "digérait"
#             intervals [173]:
#                 xmin = 63.03712
#                 xmax = 63.14712
#                 text = "un"
#             intervals [174]:
#                 xmin = 63.14712
#                 xmax = 64.27712
#                 text = "éléphant"
#             intervals [175]:
#                 xmin = 64.27712
#                 xmax = 64.62712
#                 text = ""
#             intervals [176]:
#                 xmin = 64.62712
#                 xmax = 64.86712
#                 text = "j'ai"
#             intervals [177]:
#                 xmin = 64.86712
#                 xmax = 65.22712
#                 text = "alors"
#             intervals [178]:
#                 xmin = 65.22712
#                 xmax = 65.84712
#                 text = "dessiné"
#             intervals [179]:
#                 xmin = 65.84712
#                 xmax = 66.38712
#                 text = "l'intérieur"
#             intervals [180]:
#                 xmin = 66.38712
#                 xmax = 66.46712
#                 text = "du"
#             intervals [181]:
#                 xmin = 66.46712
#                 xmax = 66.90712
#                 text = "serpent"
#             intervals [182]:
#                 xmin = 66.90712
#                 xmax = 67.21712
#                 text = "boa"
#             intervals [183]:
#                 xmin = 67.21712
#                 xmax = 67.89712
#                 text = "afin"
#             intervals [184]:
#                 xmin = 67.89712
#                 xmax = 67.99712
#                 text = "que"
#             intervals [185]:
#                 xmin = 67.99712
#                 xmax = 68.08712
#                 text = "les"
#             intervals [186]:
#                 xmin = 68.08712
#                 xmax = 68.33712
#                 text = "grandes"
#             intervals [187]:
#                 xmin = 68.33712
#                 xmax = 68.73712
#                 text = "personnes"
#             intervals [188]:
#                 xmin = 68.73712
#                 xmax = 68.95712
#                 text = "puissent"
#             intervals [189]:
#                 xmin = 68.95712
#                 xmax = 69.63712
#                 text = "comprendre"
#             intervals [190]:
#                 xmin = 69.63712
#                 xmax = 70.17712
#                 text = ""
#             intervals [191]:
#                 xmin = 70.17712
#                 xmax = 70.54712
#                 text = "elles"
#             intervals [192]:
#                 xmin = 70.54712
#                 xmax = 70.74712
#                 text = "ont"
#             intervals [193]:
#                 xmin = 70.74712
#                 xmax = 70.89712
#                 text = ""
#             intervals [194]:
#                 xmin = 70.89712
#                 xmax = 71.57712
#                 text = "toujours"
#             intervals [195]:
#                 xmin = 71.57712
#                 xmax = 71.94712
#                 text = "besoin"
#             intervals [196]:
#                 xmin = 71.94712
#                 xmax = 72.70712
#                 text = "d'explications"
#             intervals [197]:
#                 xmin = 72.70712
#                 xmax = 73.54712
#                 text = ""
#             intervals [198]:
#                 xmin = 73.54712
#                 xmax = 73.75712
#                 text = "mon"
#             intervals [199]:
#                 xmin = 73.75712
#                 xmax = 74.15712
#                 text = "dessin"
#             intervals [200]:
#                 xmin = 74.15712
#                 xmax = 74.58712
#                 text = "numéro"
#             intervals [201]:
#                 xmin = 74.58712
#                 xmax = 74.79712
#                 text = "zwei"
#             intervals [202]:
#                 xmin = 74.79712
#                 xmax = 75.02712
#                 text = ""
#             intervals [203]:
#                 xmin = 75.02712
#                 xmax = 75.31712
#                 text = "était"
#             intervals [204]:
#                 xmin = 75.31712
#                 xmax = 75.55712
#                 text = "comme"
#             intervals [205]:
#                 xmin = 75.55712
#                 xmax = 75.60712
#                 text = ""
#             intervals [206]:
#                 xmin = 75.60712
#                 xmax = 75.76712
#                 text = "ça"
#             intervals [207]:
#                 xmin = 75.76712
#                 xmax = 77.19712
#                 text = ""
#             intervals [208]:
#                 xmin = 77.19712
#                 xmax = 77.34712
#                 text = "les"
#             intervals [209]:
#                 xmin = 77.34712
#                 xmax = 77.67712
#                 text = "grandes"
#             intervals [210]:
#                 xmin = 77.67712
#                 xmax = 78.16712
#                 text = "personnes"
#             intervals [211]:
#                 xmin = 78.16712
#                 xmax = 78.31712
#                 text = "m'ont"
#             intervals [212]:
#                 xmin = 78.31712
#                 xmax = 78.92712
#                 text = "conseillé"
#             intervals [213]:
#                 xmin = 78.92712
#                 xmax = 79.06712
#                 text = "de"
#             intervals [214]:
#                 xmin = 79.06712
#                 xmax = 79.49712
#                 text = "laisser"
#             intervals [215]:
#                 xmin = 79.49712
#                 xmax = 79.61712
#                 text = "de"
#             intervals [216]:
#                 xmin = 79.61712
#                 xmax = 80.07712
#                 text = "côté"
#             intervals [217]:
#                 xmin = 80.07712
#                 xmax = 80.34712
#                 text = "les"
#             intervals [218]:
#                 xmin = 80.34712
#                 xmax = 80.80712
#                 text = "dessins"
#             intervals [219]:
#                 xmin = 80.80712
#                 xmax = 80.87712
#                 text = "de"
#             intervals [220]:
#                 xmin = 80.87712
#                 xmax = 81.42712
#                 text = "serpents"
#             intervals [221]:
#                 xmin = 81.42712
#                 xmax = 81.73712
#                 text = "boas"
#             intervals [222]:
#                 xmin = 81.73712
#                 xmax = 82.36712
#                 text = "ouverts"
#             intervals [223]:
#                 xmin = 82.36712
#                 xmax = 82.61712
#                 text = "ou"
#             intervals [224]:
#                 xmin = 82.61712
#                 xmax = 83.09712
#                 text = "fermés"
#             intervals [225]:
#                 xmin = 83.09712
#                 xmax = 83.45712
#                 text = "et"
#             intervals [226]:
#                 xmin = 83.45712
#                 xmax = 83.53712
#                 text = "de"
#             intervals [227]:
#                 xmin = 83.53712
#                 xmax = 84.19712
#                 text = "m'intéresser"
#             intervals [228]:
#                 xmin = 84.19712
#                 xmax = 84.65712
#                 text = "plutôt"
#             intervals [229]:
#                 xmin = 84.65712
#                 xmax = 84.69712
#                 text = "à"
#             intervals [230]:
#                 xmin = 84.69712
#                 xmax = 84.88712
#                 text = "la"
#             intervals [231]:
#                 xmin = 84.88712
#                 xmax = 85.60712
#                 text = "géographie"
#             intervals [232]:
#                 xmin = 85.60712
#                 xmax = 85.79712
#                 text = ""
#             intervals [233]:
#                 xmin = 85.79712
#                 xmax = 85.91712
#                 text = "à"
#             intervals [234]:
#                 xmin = 85.91712
#                 xmax = 86.62712
#                 text = "l'histoire"
#             intervals [235]:
#                 xmin = 86.62712
#                 xmax = 86.80712
#                 text = "au"
#             intervals [236]:
#                 xmin = 86.80712
#                 xmax = 87.43712
#                 text = "calcul"
#             intervals [237]:
#                 xmin = 87.43712
#                 xmax = 87.70712
#                 text = "et"
#             intervals [238]:
#                 xmin = 87.70712
#                 xmax = 87.78712
#                 text = "à"
#             intervals [239]:
#                 xmin = 87.78712
#                 xmax = 87.96712
#                 text = "la"
#             intervals [240]:
#                 xmin = 87.96712
#                 xmax = 88.60712
#                 text = "grammaire"
#             intervals [241]:
#                 xmin = 88.60712
#                 xmax = 89.60712
#                 text = ""
#             intervals [242]:
#                 xmin = 89.60712
#                 xmax = 89.88712
#                 text = "c'est"
#             intervals [243]:
#                 xmin = 89.88712
#                 xmax = 90.31712
#                 text = "ainsi"
#             intervals [244]:
#                 xmin = 90.31712
#                 xmax = 90.46712
#                 text = "que"
#             intervals [245]:
#                 xmin = 90.46712
#                 xmax = 90.68712
#                 text = "j'ai"
#             intervals [246]:
#                 xmin = 90.68712
#                 xmax = 91.24712
#                 text = "abandonné"
#             intervals [247]:
#                 xmin = 91.24712
#                 xmax = 91.60712
#                 text = "à"
#             intervals [248]:
#                 xmin = 91.60712
#                 xmax = 91.87712
#                 text = "l'âge"
#             intervals [249]:
#                 xmin = 91.87712
#                 xmax = 92.05712
#                 text = "de"
#             intervals [250]:
#                 xmin = 92.05712
#                 xmax = 92.47712
#                 text = "six"
#             intervals [251]:
#                 xmin = 92.47712
#                 xmax = 92.64712
#                 text = "ans"
#             intervals [252]:
#                 xmin = 92.64712
#                 xmax = 93.01712
#                 text = ""
#             intervals [253]:
#                 xmin = 93.01712
#                 xmax = 93.30712
#                 text = "une"
#             intervals [254]:
#                 xmin = 93.30712
#                 xmax = 94.18712
#                 text = "magnifique"
#             intervals [255]:
#                 xmin = 94.18712
#                 xmax = 94.56712
#                 text = "carrière"
#             intervals [256]:
#                 xmin = 94.56712
#                 xmax = 94.69712
#                 text = "de"
#             intervals [257]:
#                 xmin = 94.69712
#                 xmax = 95.21712
#                 text = "peintre"
#             intervals [258]:
#                 xmin = 95.21712
#                 xmax = 95.83712
#                 text = ""
#             intervals [259]:
#                 xmin = 95.83712
#                 xmax = 96.21712
#                 text = "j'avais"
#             intervals [260]:
#                 xmin = 96.21712
#                 xmax = 96.51712
#                 text = "été"
#             intervals [261]:
#                 xmin = 96.51712
#                 xmax = 97.45712
#                 text = "découragé"
#             intervals [262]:
#                 xmin = 97.45712
#                 xmax = 97.62712
#                 text = "par"
#             intervals [263]:
#                 xmin = 97.62712
#                 xmax = 98.38712
#                 text = "l'insuccès"
#             intervals [264]:
#                 xmin = 98.38712
#                 xmax = 98.49712
#                 text = "de"
#             intervals [265]:
#                 xmin = 98.49712
#                 xmax = 98.68712
#                 text = "mon"
#             intervals [266]:
#                 xmin = 98.68712
#                 xmax = 99.07712
#                 text = "dessin"
#             intervals [267]:
#                 xmin = 99.07712
#                 xmax = 99.52712
#                 text = "numéro"
#             intervals [268]:
#                 xmin = 99.52712
#                 xmax = 99.73712
#                 text = "eins"
#             intervals [269]:
#                 xmin = 99.73712
#                 xmax = 100.05712
#                 text = ""
#             intervals [270]:
#                 xmin = 100.05712
#                 xmax = 100.24712
#                 text = "et"
#             intervals [271]:
#                 xmin = 100.24712
#                 xmax = 100.37712
#                 text = "de"
#             intervals [272]:
#                 xmin = 100.37712
#                 xmax = 100.56712
#                 text = "mon"
#             intervals [273]:
#                 xmin = 100.56712
#                 xmax = 100.94712
#                 text = "dessin"
#             intervals [274]:
#                 xmin = 100.94712
#                 xmax = 101.36712
#                 text = "numéro"
#             intervals [275]:
#                 xmin = 101.36712
#                 xmax = 101.61712
#                 text = "zwei"
#             intervals [276]:
#                 xmin = 101.61712
#                 xmax = 102.67712
#                 text = ""
#             intervals [277]:
#                 xmin = 102.67712
#                 xmax = 102.79712
#                 text = "les"
#             intervals [278]:
#                 xmin = 102.79712
#                 xmax = 103.12712
#                 text = "grandes"
#             intervals [279]:
#                 xmin = 103.12712
#                 xmax = 103.66712
#                 text = "personnes"
#             intervals [280]:
#                 xmin = 103.66712
#                 xmax = 103.74712
#                 text = "ne"
#             intervals [281]:
#                 xmin = 103.74712
#                 xmax = 104.28712
#                 text = "comprennent"
#             intervals [282]:
#                 xmin = 104.28712
#                 xmax = 104.79712
#                 text = "jamais"
#             intervals [283]:
#                 xmin = 104.79712
#                 xmax = 105.00712
#                 text = "rien"
#             intervals [284]:
#                 xmin = 105.00712
#                 xmax = 105.25712
#                 text = "toutes"
#             intervals [285]:
#                 xmin = 105.25712
#                 xmax = 105.54712
#                 text = "seules"
#             intervals [286]:
#                 xmin = 105.54712
#                 xmax = 105.81712
#                 text = ""
#             intervals [287]:
#                 xmin = 105.81712
#                 xmax = 106.03712
#                 text = "et"
#             intervals [288]:
#                 xmin = 106.03712
#                 xmax = 106.21712
#                 text = "c'est"
#             intervals [289]:
#                 xmin = 106.21712
#                 xmax = 106.83712
#                 text = "fatigant"
#             intervals [290]:
#                 xmin = 106.83712
#                 xmax = 106.94712
#                 text = ""
#             intervals [291]:
#                 xmin = 106.94712
#                 xmax = 107.08712
#                 text = "pour"
#             intervals [292]:
#                 xmin = 107.08712
#                 xmax = 107.28712
#                 text = "les"
#             intervals [293]:
#                 xmin = 107.28712
#                 xmax = 107.67712
#                 text = "enfants"
#             intervals [294]:
#                 xmin = 107.67712
#                 xmax = 108.05712
#                 text = ""
#             intervals [295]:
#                 xmin = 108.05712
#                 xmax = 108.21712
#                 text = "de"
#             intervals [296]:
#                 xmin = 108.21712
#                 xmax = 108.32712
#                 text = ""
#             intervals [297]:
#                 xmin = 108.32712
#                 xmax = 108.82712
#                 text = "toujours"
#             intervals [298]:
#                 xmin = 108.82712
#                 xmax = 108.95712
#                 text = "et"
#             intervals [299]:
#                 xmin = 108.95712
#                 xmax = 109.04712
#                 text = ""
#             intervals [300]:
#                 xmin = 109.04712
#                 xmax = 109.61712
#                 text = "toujours"
#             intervals [301]:
#                 xmin = 109.61712
#                 xmax = 109.92712
#                 text = "leur"
#             intervals [302]:
#                 xmin = 109.92712
#                 xmax = 110.18712
#                 text = "donner"
#             intervals [303]:
#                 xmin = 110.18712
#                 xmax = 110.41712
#                 text = "des"
#             intervals [304]:
#                 xmin = 110.41712
#                 xmax = 111.18712
#                 text = "explications"
#             intervals [305]:
#                 xmin = 111.18712
#                 xmax = 112.23712
#                 text = ""
#             intervals [306]:
#                 xmin = 112.23712
#                 xmax = 112.46712
#                 text = "j'ai"
#             intervals [307]:
#                 xmin = 112.46712
#                 xmax = 112.67712
#                 text = "donc"
#             intervals [308]:
#                 xmin = 112.67712
#                 xmax = 112.88712
#                 text = "dû"
#             intervals [309]:
#                 xmin = 112.88712
#                 xmax = 113.31712
#                 text = "choisir"
#             intervals [310]:
#                 xmin = 113.31712
#                 xmax = 113.49712
#                 text = "un"
#             intervals [311]:
#                 xmin = 113.49712
#                 xmax = 113.78712
#                 text = "autre"
#             intervals [312]:
#                 xmin = 113.78712
#                 xmax = 114.21712
#                 text = "métier"
#             intervals [313]:
#                 xmin = 114.21712
#                 xmax = 114.57712
#                 text = ""
#             intervals [314]:
#                 xmin = 114.57712
#                 xmax = 114.73712
#                 text = "et"
#             intervals [315]:
#                 xmin = 114.73712
#                 xmax = 114.89712
#                 text = "j'ai"
#             intervals [316]:
#                 xmin = 114.89712
#                 xmax = 115.25712
#                 text = "appris"
#             intervals [317]:
#                 xmin = 115.25712
#                 xmax = 115.37712
#                 text = "à"
#             intervals [318]:
#                 xmin = 115.37712
#                 xmax = 115.83712
#                 text = "piloter"
#             intervals [319]:
#                 xmin = 115.83712
#                 xmax = 116.04712
#                 text = "des"
#             intervals [320]:
#                 xmin = 116.04712
#                 xmax = 116.48712
#                 text = "avions"
#             intervals [321]:
#                 xmin = 116.48712
#                 xmax = 117.41712
#                 text = ""
#             intervals [322]:
#                 xmin = 117.41712
#                 xmax = 117.61712
#                 text = "j'ai"
#             intervals [323]:
#                 xmin = 117.61712
#                 xmax = 117.98712
#                 text = "volé"
#             intervals [324]:
#                 xmin = 117.98712
#                 xmax = 118.07712
#                 text = "un"
#             intervals [325]:
#                 xmin = 118.07712
#                 xmax = 118.19712
#                 text = "peu"
#             intervals [326]:
#                 xmin = 118.19712
#                 xmax = 118.68712
#                 text = "partout"
#             intervals [327]:
#                 xmin = 118.68712
#                 xmax = 118.72712
#                 text = "dans"
#             intervals [328]:
#                 xmin = 118.72712
#                 xmax = 118.80712
#                 text = "le"
#             intervals [329]:
#                 xmin = 118.80712
#                 xmax = 119.27712
#                 text = "monde"
#             intervals [330]:
#                 xmin = 119.27712
#                 xmax = 119.66712
#                 text = ""
#             intervals [331]:
#                 xmin = 119.66712
#                 xmax = 119.77712
#                 text = "et"
#             intervals [332]:
#                 xmin = 119.77712
#                 xmax = 119.97712
#                 text = "la"
#             intervals [333]:
#                 xmin = 119.97712
#                 xmax = 120.73712
#                 text = "géographie"
#             intervals [334]:
#                 xmin = 120.73712
#                 xmax = 120.80712
#                 text = ""
#             intervals [335]:
#                 xmin = 120.80712
#                 xmax = 121.07712
#                 text = "c'est"
#             intervals [336]:
#                 xmin = 121.07712
#                 xmax = 121.58712
#                 text = "exact"
#             intervals [337]:
#                 xmin = 121.58712
#                 xmax = 121.73712
#                 text = ""
#             intervals [338]:
#                 xmin = 121.73712
#                 xmax = 121.95712
#                 text = "m'a"
#             intervals [339]:
#                 xmin = 121.95712
#                 xmax = 122.36712
#                 text = "beaucoup"
#             intervals [340]:
#                 xmin = 122.36712
#                 xmax = 122.74712
#                 text = "servi"
#             intervals [341]:
#                 xmin = 122.74712
#                 xmax = 123.41712
#                 text = ""
#             intervals [342]:
#                 xmin = 123.41712
#                 xmax = 123.54712
#                 text = "je"
#             intervals [343]:
#                 xmin = 123.54712
#                 xmax = 123.90712
#                 text = "savais"
#             intervals [344]:
#                 xmin = 123.90712
#                 xmax = 124.57712
#                 text = "reconnaître"
#             intervals [345]:
#                 xmin = 124.57712
#                 xmax = 124.73712
#                 text = "du"
#             intervals [346]:
#                 xmin = 124.73712
#                 xmax = 125.30712
#                 text = "premier"
#             intervals [347]:
#                 xmin = 125.30712
#                 xmax = 125.48712
#                 text = "coup"
#             intervals [348]:
#                 xmin = 125.48712
#                 xmax = 125.90712
#                 text = "d'oeil"
#             intervals [349]:
#                 xmin = 125.90712
#                 xmax = 126.03712
#                 text = ""
#             intervals [350]:
#                 xmin = 126.03712
#                 xmax = 126.25712
#                 text = "la"
#             intervals [351]:
#                 xmin = 126.25712
#                 xmax = 126.72712
#                 text = "chine"
#             intervals [352]:
#                 xmin = 126.72712
#                 xmax = 126.83712
#                 text = "de"
#             intervals [353]:
#                 xmin = 126.83712
#                 xmax = 127.50712
#                 text = "l'arizona"
#             intervals [354]:
#                 xmin = 127.50712
#                 xmax = 128.05712
#                 text = ""
#             intervals [355]:
#                 xmin = 128.05712
#                 xmax = 128.24712
#                 text = "c'est"
#             intervals [356]:
#                 xmin = 128.24712
#                 xmax = 128.55712
#                 text = "très"
#             intervals [357]:
#                 xmin = 128.55712
#                 xmax = 129.09712
#                 text = "utile"
#             intervals [358]:
#                 xmin = 129.09712
#                 xmax = 129.20712
#                 text = ""
#             intervals [359]:
#                 xmin = 129.20712
#                 xmax = 129.40712
#                 text = "si"
#             intervals [360]:
#                 xmin = 129.40712
#                 xmax = 129.55712
#                 text = "l'on"
#             intervals [361]:
#                 xmin = 129.55712
#                 xmax = 129.72712
#                 text = "s'est"
#             intervals [362]:
#                 xmin = 129.72712
#                 xmax = 130.14712
#                 text = "égaré"
#             intervals [363]:
#                 xmin = 130.14712
#                 xmax = 130.41712
#                 text = "pendant"
#             intervals [364]:
#                 xmin = 130.41712
#                 xmax = 130.51712
#                 text = "la"
#             intervals [365]:
#                 xmin = 130.51712
#                 xmax = 130.81712
#                 text = "nuit"
#             intervals [366]:
#                 xmin = 130.81712
#                 xmax = 131.99712
#                 text = ""
#             intervals [367]:
#                 xmin = 131.99712
#                 xmax = 132.17712
#                 text = "j'ai"
#             intervals [368]:
#                 xmin = 132.17712
#                 xmax = 132.84712
#                 text = "ainsi"
#             intervals [369]:
#                 xmin = 132.84712
#                 xmax = 132.94712
#                 text = ""
#             intervals [370]:
#                 xmin = 132.94712
#                 xmax = 133.06712
#                 text = "eu"
#             intervals [371]:
#                 xmin = 133.06712
#                 xmax = 133.11712
#                 text = "au"
#             intervals [372]:
#                 xmin = 133.11712
#                 xmax = 133.34712
#                 text = "cours"
#             intervals [373]:
#                 xmin = 133.34712
#                 xmax = 133.41712
#                 text = "de"
#             intervals [374]:
#                 xmin = 133.41712
#                 xmax = 133.64712
#                 text = "ma"
#             intervals [375]:
#                 xmin = 133.64712
#                 xmax = 133.84712
#                 text = "vie"
#             intervals [376]:
#                 xmin = 133.84712
#                 xmax = 134.15712
#                 text = ""
#             intervals [377]:
#                 xmin = 134.15712
#                 xmax = 134.33712
#                 text = "des"
#             intervals [378]:
#                 xmin = 134.33712
#                 xmax = 134.48712
#                 text = ""
#             intervals [379]:
#                 xmin = 134.48712
#                 xmax = 134.74712
#                 text = "tas"
#             intervals [380]:
#                 xmin = 134.74712
#                 xmax = 134.83712
#                 text = "de"
#             intervals [381]:
#                 xmin = 134.83712
#                 xmax = 135.39712
#                 text = "contacts"
#             intervals [382]:
#                 xmin = 135.39712
#                 xmax = 135.60712
#                 text = "avec"
#             intervals [383]:
#                 xmin = 135.60712
#                 xmax = 135.86712
#                 text = "des"
#             intervals [384]:
#                 xmin = 135.86712
#                 xmax = 135.97712
#                 text = ""
#             intervals [385]:
#                 xmin = 135.97712
#                 xmax = 136.18712
#                 text = "tas"
#             intervals [386]:
#                 xmin = 136.18712
#                 xmax = 136.31712
#                 text = "de"
#             intervals [387]:
#                 xmin = 136.31712
#                 xmax = 136.55712
#                 text = "gens"
#             intervals [388]:
#                 xmin = 136.55712
# ...
#                 xmin = 597.79712
#                 xmax = 597.91712
#                 text = "r"
#             intervals [6102]:
#                 xmin = 597.91712
#                 xmax = 597.95712
#                 text = "I"
#             intervals [6103]:
#                 xmin = 597.95712
#                 xmax = 597.98712
#                 text = "n"
#             intervals [6104]:
#                 xmin = 597.98712
#                 xmax = 598.10712
#                 text = "ts"
#             intervals [6105]:
#                 xmin = 598.10712
#                 xmax = 598.18712
#                 text = "r"
#             intervals [6106]:
#                 xmin = 598.18712
#                 xmax = 598.22712
#                 text = "e"
#             intervals [6107]:
#                 xmin = 598.22712
#                 xmax = 598.31712
#                 text = "m"
#             intervals [6108]:
#                 xmin = 598.31712
#                 xmax = 598.36712
#                 text = "a"
#             intervals [6109]:
#                 xmin = 598.36712
#                 xmax = 598.44712
#                 text = "r"
#             intervals [6110]:
#                 xmin = 598.44712
#                 xmax = 598.53712
#                 text = "k"
#             intervals [6111]:
#                 xmin = 598.53712
#                 xmax = 598.57712
#                 text = "v"
#             intervals [6112]:
#                 xmin = 598.57712
#                 xmax = 598.71712
#                 text = "a:"
#             intervals [6113]:
#                 xmin = 598.71712
#                 xmax = 598.78712
#                 text = "g"
#             intervals [6114]:
#                 xmin = 598.78712
#                 xmax = 598.85712
#                 text = "r"
#             intervals [6115]:
#                 xmin = 598.85712
#                 xmax = 599.01712
#                 text = "a"
#             intervals [6116]:
#                 xmin = 599.01712
#                 xmax = 599.04712
#                 text = "v"
#             intervals [6117]:
#                 xmin = 599.04712
#                 xmax = 599.07712
#                 text = "?"
#             intervals [6118]:
#                 xmin = 599.07712
#                 xmax = 599.13712
#                 text = "e"
#             intervals [6119]:
#                 xmin = 599.13712
#                 xmax = 599.26712
#                 text = "m"
#             intervals [6120]:
#                 xmin = 599.26712
#                 xmax = 599.29712
#                 text = "E"
#             intervals [6121]:
#                 xmin = 599.29712
#                 xmax = 599.36712
#                 text = "n"
#             intervals [6122]:
#                 xmin = 599.36712
#                 xmax = 600.20712
#                 text = "<p:>"
#             intervals [6123]:
#                 xmin = 600.20712
#                 xmax = 600.26712
#                 text = "k"
#             intervals [6124]:
#                 xmin = 600.26712
#                 xmax = 600.31712
#                 text = "a"
#             intervals [6125]:
#                 xmin = 600.31712
#                 xmax = 600.35712
#                 text = "n"
#             intervals [6126]:
#                 xmin = 600.35712
#                 xmax = 600.39712
#                 text = "E"
#             intervals [6127]:
#                 xmin = 600.39712
#                 xmax = 600.51712
#                 text = "f"
#             intervals [6128]:
#                 xmin = 600.51712
#                 xmax = 600.61712
#                 text = "aI"
#             intervals [6129]:
#                 xmin = 600.61712
#                 xmax = 600.64712
#                 text = "r"
#             intervals [6130]:
#                 xmin = 600.64712
#                 xmax = 600.75712
#                 text = "i:"
#             intervals [6131]:
#                 xmin = 600.75712
#                 xmax = 600.78712
#                 text = "n"
#             intervals [6132]:
#                 xmin = 600.78712
#                 xmax = 601.04712
#                 text = "<p:>"
#             intervals [6133]:
#                 xmin = 601.04712
#                 xmax = 601.16712
#                 text = "ts"
#             intervals [6134]:
#                 xmin = 601.16712
#                 xmax = 601.19712
#                 text = "E"
#             intervals [6135]:
#                 xmin = 601.19712
#                 xmax = 601.22712
#                 text = "s"
#             intervals [6136]:
#                 xmin = 601.22712
#                 xmax = 601.31712
#                 text = "t"
#             intervals [6137]:
#                 xmin = 601.31712
#                 xmax = 601.40712
#                 text = "E"
#             intervals [6138]:
#                 xmin = 601.40712
#                 xmax = 601.45712
#                 text = "l"
#             intervals [6139]:
#                 xmin = 601.45712
#                 xmax = 601.48712
#                 text = "@"
#             intervals [6140]:
#                 xmin = 601.48712
#                 xmax = 601.53712
#                 text = "m"
#             intervals [6141]:
#                 xmin = 601.53712
#                 xmax = 601.56712
#                 text = "E"
#             intervals [6142]:
#                 xmin = 601.56712
#                 xmax = 601.60712
#                 text = "n"
#             intervals [6143]:
#                 xmin = 601.60712
#                 xmax = 601.67712
#                 text = "t"
#             intervals [6144]:
#                 xmin = 601.67712
#                 xmax = 601.70712
#                 text = "p"
#             intervals [6145]:
#                 xmin = 601.70712
#                 xmax = 601.79712
#                 text = "@"
#             intervals [6146]:
#                 xmin = 601.79712
#                 xmax = 601.93712
#                 text = "t"
#             intervals [6147]:
#                 xmin = 601.93712
#                 xmax = 602.03712
#                 text = "i:"
#             intervals [6148]:
#                 xmin = 602.03712
#                 xmax = 602.17712
#                 text = "S"
#             intervals [6149]:
#                 xmin = 602.17712
#                 xmax = 602.25712
#                 text = "e:"
#             intervals [6150]:
#                 xmin = 602.25712
#                 xmax = 602.36712
#                 text = "m"
#             intervals [6151]:
#                 xmin = 602.36712
#                 xmax = 602.44712
#                 text = "O"
#             intervals [6152]:
#                 xmin = 602.44712
#                 xmax = 602.47712
#                 text = "I"
#             intervals [6153]:
#                 xmin = 602.47712
#                 xmax = 603.32712
#                 text = "<p:>"
#             intervals [6154]:
#                 xmin = 603.32712
#                 xmax = 603.40712
#                 text = "?"
#             intervals [6155]:
#                 xmin = 603.40712
#                 xmax = 603.54712
#                 text = "E"
#             intervals [6156]:
#                 xmin = 603.54712
#                 xmax = 603.63712
#                 text = "t"
#             intervals [6157]:
#                 xmin = 603.63712
#                 xmax = 603.73712
#                 text = "?"
#             intervals [6158]:
#                 xmin = 603.73712
#                 xmax = 603.83712
#                 text = "a"
#             intervals [6159]:
#                 xmin = 603.83712
#                 xmax = 603.87712
#                 text = "v"
#             intervals [6160]:
#                 xmin = 603.87712
#                 xmax = 603.94712
#                 text = "E"
#             intervals [6161]:
#                 xmin = 603.94712
#                 xmax = 604.03712
#                 text = "k"
#             intervals [6162]:
#                 xmin = 604.03712
#                 xmax = 604.11712
#                 text = "U"
#             intervals [6163]:
#                 xmin = 604.11712
#                 xmax = 604.14712
#                 text = "n"
#             intervals [6164]:
#                 xmin = 604.14712
#                 xmax = 604.20712
#                 text = "p"
#             intervals [6165]:
#                 xmin = 604.20712
#                 xmax = 604.24712
#                 text = "OY"
#             intervals [6166]:
#                 xmin = 604.24712
#                 xmax = 604.32712
#                 text = "d"
#             intervals [6167]:
#                 xmin = 604.32712
#                 xmax = 604.39712
#                 text = "e"
#             intervals [6168]:
#                 xmin = 604.39712
#                 xmax = 604.45712
#                 text = "m"
#             intervals [6169]:
#                 xmin = 604.45712
#                 xmax = 604.53712
#                 text = "e:"
#             intervals [6170]:
#                 xmin = 604.53712
#                 xmax = 604.57712
#                 text = "l"
#             intervals [6171]:
#                 xmin = 604.57712
#                 xmax = 604.62712
#                 text = "a"
#             intervals [6172]:
#                 xmin = 604.62712
#                 xmax = 604.67712
#                 text = "n"
#             intervals [6173]:
#                 xmin = 604.67712
#                 xmax = 604.76712
#                 text = "k"
#             intervals [6174]:
#                 xmin = 604.76712
#                 xmax = 604.83712
#                 text = "o"
#             intervals [6175]:
#                 xmin = 604.83712
#                 xmax = 604.87712
#                 text = "l"
#             intervals [6176]:
#                 xmin = 604.87712
#                 xmax = 605.01712
#                 text = "j"
#             intervals [6177]:
#                 xmin = 605.01712
#                 xmax = 605.04712
#                 text = "@"
#             intervals [6178]:
#                 xmin = 605.04712
#                 xmax = 605.15712
#                 text = "p"
#             intervals [6179]:
#                 xmin = 605.15712
#                 xmax = 605.21712
#                 text = "OY"
#             intervals [6180]:
#                 xmin = 605.21712
#                 xmax = 605.26712
#                 text = "t"
#             intervals [6181]:
#                 xmin = 605.26712
#                 xmax = 605.29712
#                 text = "?"
#             intervals [6182]:
#                 xmin = 605.29712
#                 xmax = 605.44712
#                 text = "e"
#             intervals [6183]:
#                 xmin = 605.44712
#                 xmax = 605.48712
#                 text = "t"
#             intervals [6184]:
#                 xmin = 605.48712
#                 xmax = 605.59712
#                 text = "r"
#             intervals [6185]:
#                 xmin = 605.59712
#                 xmax = 605.66712
#                 text = "@"
#             intervals [6186]:
#                 xmin = 605.66712
#                 xmax = 605.71712
#                 text = "<p:>"
#             intervals [6187]:
#                 xmin = 605.71712
#                 xmax = 605.86712
#                 text = "?"
#             intervals [6188]:
#                 xmin = 605.86712
#                 xmax = 605.95712
#                 text = "I"
#             intervals [6189]:
#                 xmin = 605.95712
#                 xmax = 605.99712
#                 text = "l"
#             intervals [6190]:
#                 xmin = 605.99712
#                 xmax = 606.11712
#                 text = "a"
#             intervals [6191]:
#                 xmin = 606.11712
#                 xmax = 606.20712
#                 text = "j"
#             intervals [6192]:
#                 xmin = 606.20712
#                 xmax = 606.24712
#                 text = "o:"
#             intervals [6193]:
#                 xmin = 606.24712
#                 xmax = 606.28712
#                 text = "u:"
#             intervals [6194]:
#                 xmin = 606.28712
#                 xmax = 606.37712
#                 text = "t"
#             intervals [6195]:
#                 xmin = 606.37712
#                 xmax = 606.53712
#                 text = "a"
#             intervals [6196]:
#                 xmin = 606.53712
#                 xmax = 607.36712
#                 text = "<p:>"
#             intervals [6197]:
#                 xmin = 607.36712
#                 xmax = 607.44712
#                 text = "d"
#             intervals [6198]:
#                 xmin = 607.44712
#                 xmax = 607.53712
#                 text = "r"
#             intervals [6199]:
#                 xmin = 607.53712
#                 xmax = 607.61712
#                 text = "OY"
#             intervals [6200]:
#                 xmin = 607.61712
#                 xmax = 607.64712
#                 text = "t"
#             intervals [6201]:
#                 xmin = 607.64712
#                 xmax = 607.67712
#                 text = "d"
#             intervals [6202]:
#                 xmin = 607.67712
#                 xmax = 607.72712
#                 text = "e"
#             intervals [6203]:
#                 xmin = 607.72712
#                 xmax = 607.80712
#                 text = "v"
#             intervals [6204]:
#                 xmin = 607.80712
#                 xmax = 607.89712
#                 text = "a"
#             intervals [6205]:
#                 xmin = 607.89712
#                 xmax = 607.92712
#                 text = "n"
#             intervals [6206]:
#                 xmin = 607.92712
#                 xmax = 608.08712
#                 text = "s"
#             intervals [6207]:
#                 xmin = 608.08712
#                 xmax = 608.19712
#                 text = "OY"
#             intervals [6208]:
#                 xmin = 608.19712
#                 xmax = 608.43712
#                 text = "O"
#             intervals [6209]:
#                 xmin = 608.43712
#                 xmax = 608.46712
#                 text = "n"
#             intervals [6210]:
#                 xmin = 608.46712
#                 xmax = 608.51712
#                 text = "n"
#             intervals [6211]:
#                 xmin = 608.51712
#                 xmax = 608.56712
#                 text = "E"
#             intervals [6212]:
#                 xmin = 608.56712
#                 xmax = 608.63712
#                 text = "p"
#             intervals [6213]:
#                 xmin = 608.63712
#                 xmax = 608.68712
#                 text = "OY"
#             intervals [6214]:
#                 xmin = 608.68712
#                 xmax = 608.71712
#                 text = "t"
#             intervals [6215]:
#                 xmin = 608.71712
#                 xmax = 608.74712
#                 text = "p"
#             intervals [6216]:
#                 xmin = 608.74712
#                 xmax = 608.84712
#                 text = "a"
#             intervals [6217]:
#                 xmin = 608.84712
#                 xmax = 608.92712
#                 text = "s"
#             intervals [6218]:
#                 xmin = 608.92712
#                 xmax = 608.96712
#                 text = "a"
#             intervals [6219]:
#                 xmin = 608.96712
#                 xmax = 609.02712
#                 text = "l"
#             intervals [6220]:
#                 xmin = 609.02712
#                 xmax = 609.08712
#                 text = "6"
#             intervals [6221]:
#                 xmin = 609.08712
#                 xmax = 609.15712
#                 text = "b"
#             intervals [6222]:
#                 xmin = 609.15712
#                 xmax = 609.24712
#                 text = "i:"
#             intervals [6223]:
#                 xmin = 609.24712
#                 xmax = 609.27712
#                 text = "n"
#             intervals [6224]:
#                 xmin = 609.27712
#                 xmax = 609.30712
#                 text = "l"
#             intervals [6225]:
#                 xmin = 609.30712
#                 xmax = 609.33712
#                 text = "?"
#             intervals [6226]:
#                 xmin = 609.33712
#                 xmax = 609.40712
#                 text = "o:"
#             intervals [6227]:
#                 xmin = 609.40712
#                 xmax = 609.43712
#                 text = "?"
#             intervals [6228]:
#                 xmin = 609.43712
#                 xmax = 609.47712
#                 text = "i:"
#             intervals [6229]:
#                 xmin = 609.47712
#                 xmax = 609.50712
#                 text = "n"
#             intervals [6230]:
#                 xmin = 609.50712
#                 xmax = 612.591814
#                 text = "<p:>"

# %%
dict_ts_to_phoneme = {} # Dict linking timestamp to phoneme

# Get the list of phonemes, their timestamp, and create a dict based off it
for ph in grid['MAU']:

    dict_ts_to_phoneme[ph.mid] = ph.text

# %%
dict_ts_to_phoneme
# Out:
# {1.04356: '<p:>',
#  2.12712: 'l',
#  2.2221200000000003: 'O',
#  2.2921199999999997: '6',
#  2.32212: 'z',
#  2.35712: 's',
#  2.40712: 'k',
#  2.45212: 'v',
#  2.49712: '@',
#  2.54712: 'j',
#  2.62712: 'a',
#  2.70212: 'v',
#  2.7671200000000002: 'aI',
#  2.90712: 's',
#  3.01712: 'z',
#  3.11712: 'I',
#  3.21212: 'k',
#  3.24212: 's',
#  3.33712: 'a',
#  3.4571199999999997: 'n',
#  3.51212: 's',
#  3.58712: 'dZ',
#  3.87712: 'aI',
#  4.2121200000000005: '<p:>',
#  4.33212: 'f',
#  4.372120000000001: 'U',
#  4.417120000000001: 'U',
#  4.48212: 'n',
#  4.557119999999999: '@',
#  4.6321200000000005: '<p:>',
#  4.72712: 'f',
#  4.8371200000000005: 'OY',
#  4.91212: 's',
#  5.06212: '<p:>',
#  5.23212: '?',
#  5.28712: 'U',
#  5.35712: 'n',
#  5.4621200000000005: '@',
#  5.61712: 'm',
#  5.77712: 'a:',
#  5.85712: 'g',
#  5.897119999999999: 'n',
#  5.96212: 'i',
#  6.067119999999999: 'f',
#  6.15712: 'i',
#  6.22212: 'k',
#  6.28712: 'v',
#  6.36212: '@',
#  6.432119999999999: 'I',
#  6.53212: 'm',
#  6.64712: 'I',
#  6.73212: 'tS',
#  6.86712: '<p:>',
#  7.00212: 'd',
#  7.07212: 'a:',
#  7.15212: 'U',
#  7.22212: 'n',
#  7.25212: 'l',
#  7.35712: 'aI',
#  7.4671199999999995: 'r',
#  7.54712: '@',
#  7.622120000000001: 'z',
#  7.67212: 'U',
#  7.72212: '6',
#  7.76712: 's',
#  7.87712: 'l',
#  8.01212: 'a',
#  8.11712: 'f',
#  8.22212: 'o',
#  8.29712: 'r',
#  8.36212: 'E',
#  8.42212: 't',
#  8.45212: 'f',
#  8.517119999999998: 'i:',
#  8.61712: 'E',
#  8.74212: '6',
#  8.83212: 'g',
#  8.86212: '@',
#  8.932120000000001: 'k',
#  9.01212: 'v',
#  9.057120000000001: 'aI',
#  9.13212: 'z',
#  9.247119999999999: 'a',
#  9.34212: 'p',
#  9.397120000000001: '@',
#  9.46212: 'l',
#  9.56212: 'E',
#  9.63712: 'i:',
#  9.69212: 't',
#  9.81712: '<p:>',
#  9.96212: 'I',
#  10.06212: 's',
#  10.147120000000001: 't',
#  10.247119999999999: 'o',
#  10.32712: 'i:',
#  10.36212: 'r',
#  10.407119999999999: '@',
#  10.45712: 'v',
#  10.54212: 'e:',
#  10.67712: 'k',
#  10.787120000000002: 'Y',
#  10.842120000000001: 's',
#  11.337119999999999: '<p:>',
#  11.83212: 'k',
#  11.88712: 'a',
#  11.96212: 'r',
#  12.01712: 'e:',
#  12.06712: 'p',
#  12.13712: 'r',
#  12.20712: 'e:',
#  12.29212: 'z',
#  12.377120000000001: 'E',
#  12.43712: 'n',
#  12.51212: 't',
#  12.59212: 'aI',
#  12.682120000000001: 'U',
#  12.752120000000001: 'n',
#  12.82712: 'z',
#  12.907119999999999: 'E',
#  12.97212: '6',
#  13.03712: 'b',
#  13.10212: 'p',
#  13.18712: 'E',
#  13.25212: 'n',
#  13.30212: 'b',
#  13.39212: 'o',
#  13.532119999999999: 'a',
#  13.712119999999999: '<p:>',
#  13.86212: 'k',
#  13.96212: 'v',
#  14.03712: 'aI',
#  14.09712: 'a',
#  14.16712: 'v',
#  14.22712: 'a',
#  14.28712: 'l',
#  14.372119999999999: 'aI',
#  14.467120000000001: 't',
#  14.57212: 'U',
#  14.65212: 'n',
#  14.74212: 'f',
#  14.927119999999999: 'aU',
#  15.08212: 'v',
#  15.17212: '@',
#  15.52712: '<p:>',
#  15.88712: 'v',
#  16.002119999999998: 'OY',
#  16.08712: 'l',
#  16.15712: 'a',
#  16.232120000000002: 'l',
#  16.29212: 'a',
#  16.387120000000003: 'k',
#  16.49212: 'o',
#  16.567120000000003: 'p',
#  16.65712: 'i:',
#  16.762120000000003: 'd',
#  16.84212: 'u:',
#  16.90712: 'd',
#  16.97712: '@',
#  17.08712: 's',
#  17.19212: 'I',
#  17.24212: 'n',
#  17.88712: '<p:>',
#  18.54712: '?',
#  18.627119999999998: 'O',
#  18.69212: 'n',
#  18.72212: 'd',
#  18.79212: 'i',
#  18.89212: 'z',
#  18.98712: 'aI',
#  19.05712: 'd',
#  19.122120000000002: 'a:',
#  19.28212: 'l',
#  19.502119999999998: 'e',
#  19.65712: 'l',
#  19.737119999999997: 'aI',
#  19.807119999999998: 'r',
#  19.86212: '@',
#  19.96712: '<p:>',
#  20.10212: 'l',
#  20.192120000000003: 'E',
#  20.27712: 's',
#  20.33712: 'z',
#  20.39212: 'E',
#  20.45712: '6',
#  20.50712: 'b',
#  20.552120000000002: 'p',
#  20.60212: 'E',
#  20.692120000000003: 'n',
#  20.79212: 'b',
#  20.89712: 'O',
#  21.02212: 'a',
#  21.15712: '?',
#  21.317120000000003: 'a',
#  21.42212: 'v',
#  21.512120000000003: 'a:',
#  21.59212: 'l',
#  21.62212: 'E',
#  21.69212: 'n',
#  21.76212: 'l',
#  21.802120000000002: 'OY',
#  21.872120000000002: 'r',
#  21.96212: 'p',
#  22.057119999999998: 'r',
#  22.19212: 'OY',
#  22.29712: '@',
#  22.39212: '<p:>',
#  22.512120000000003: 't',
#  22.57712: 'o',
#  22.61212: '?',
#  22.64212: 'U',
#  22.697119999999998: 't',
#  22.75712: '?',
#  22.79212: 'E',
#  22.83212: 'n',
#  22.92712: 't',
#  23.06212: 'i:',
#  23.184614500000002: '6',
#  23.274603499999998: 'z',
#  23.347109: 'a',
#  23.40212: 'n',
#  23.49212: 's',
#  23.58212: 'l',
#  23.63212: 'a',
#  23.68212: 'm',
#  23.72212: 'a',
#  23.76212: 'x',
#  23.84712: '6',
#  23.96712: 'E',
#  24.03212: 'n',
#  24.122120000000002: 'z',
#  24.22712: 'u',
#  24.29712: 'i:',
#  24.362119999999997: 't',
#  24.57712: '<p:>',
#  24.84212: '?',
#  24.93212: 'I',
#  24.99212: 'l',
#  25.10212: 's',
#  25.20212: 'n',
#  25.27712: 'E',
#  25.38712: 'p',
#  25.482120000000002: 'OY',
#  25.52212: 'v',
#  25.567120000000003: 'E',
#  25.61712: 'n',
#  25.67212: 'p',
#  25.737119999999997: 'l',
#  25.78212: 'U',
#  25.81212: 's',
#  25.877119999999998: '<p:>',
#  25.96212: 'b',
#  26.06212: 'u',
#  26.18212: 'g',
#  26.31212: '6',
#  26.41712: '?',
#  26.50212: 'E',
#  26.57712: 't',
#  26.66712: '<p:>',
#  26.762120000000003: '?',
#  26.87712: 'I',
#  27.00712: 'l',
#  27.06212: 's',
#  27.127119999999998: 'd',
#  27.19212: 'O',
#  27.307119999999998: '6',
#  27.427120000000002: 'm',
#  27.46712: 'a',
#  27.50712: 'e:',
#  27.54212: 'n',
#  27.58712: 'p',
#  27.65212: 'E',
#  27.70212: 'n',
#  27.732120000000002: 't',
#  27.78712: 'a',
#  27.85212: 'n',
#  27.91212: 'l',
#  27.96712: 'E',
#  28.072119999999998: 's',
#  28.177120000000002: 'z',
#  28.23712: 'I',
#  28.29212: 'k',
#  28.322119999999998: 's',
#  28.38212: 'm',
#  28.49212: 'OY',
#  28.572119999999998: 's',
#  28.627119999999998: 'd',
#  28.71712: 'e',
#  28.78212: 'l',
#  28.81712: 'OY',
#  28.857120000000002: 'r',
#  28.89212: 'd',
#  28.927120000000002: 'I',
#  29.02212: 'j',
#  29.13212: '@',
#  29.197119999999998: 's',
#  29.26212: 't',
#  29.34212: 'j',
#  29.447119999999998: 'o:',
#  30.38212: '<p:>',
#  31.317120000000003: 'dZ',
#  31.40712: 'aI',
#  31.502119999999998: 'a',
#  31.59712: 'l',
#  31.65212: 'O',
#  31.732120000000002: '6',
#  31.802120000000002: 'z',
#  31.83212: 's',
#  31.86212: 'b',
#  31.957120000000003: '@',
#  32.05212: '?',
#  32.14712: 'aU',
#  32.29712: 'k',
#  32.43712: 'u',
#  32.52212: 'p',
#  32.55712: 'r',
#  32.63212: 'e:',
#  32.70212: 'f',
#  32.767120000000006: 'l',
#  32.85212: 'e:',
#  32.96212: 'C',
#  33.10212: 'I',
#  33.19712: 'z',
#  33.28712: 'U',
#  33.40212: '6',
#  33.472120000000004: 's',
#  33.50212: 'l',
#  33.56712: 'E',
#  33.63212: 's',
#  33.67712: 'a',
#  33.722120000000004: 'v',
#  33.75212: 'E',
#  33.78212: 'n',
#  33.872119999999995: 't',
#  33.967119999999994: 'u:',
#  34.00212: 'r',
#  34.03212: '@',
#  34.08712: 'd',
#  34.17712: 'e',
#  34.262119999999996: 'l',
#  34.31212: 'a',
#  34.362120000000004: 'Z',
#  34.502120000000005: 'U',
#  34.637119999999996: 'N',
#  34.71212: 'l',
#  34.78712: '@',
#  35.00712: '<p:>',
#  35.24212: '?',
#  35.362120000000004: 'E',
#  35.472120000000004: 't',
#  35.54712: '<p:>',
#  35.64712: '?',
#  35.752120000000005: 'a:',
#  35.82212: 'm',
#  35.90712: 'o',
#  35.98212: 'n',
#  36.02712: 't',
#  36.16212: 'U',
#  36.28212: '@',
#  36.32212: 'r',
#  36.44712: '<p:>',
#  36.637119999999996: 'dZ',
#  36.75212: 'aI',
#  36.80712: 'r',
#  36.92212: 'e:',
#  37.02212: 'U',
#  37.13212: 's',
#  37.30212: 'i',
#  37.46212: '<p:>',
#  37.58712: '?',
#  37.66712: 'a',
#  37.72712: 'v',
#  37.782120000000006: 'E',
#  37.86712: 'k',
#  37.94712: 'U',
#  38.00712: 'n',
#  38.10212: 'k',
#  38.22212: 'r',
#  38.30712: 'aI',
#  38.357119999999995: 'o:',
#  38.39212: 'n',
#  38.44212: 'd',
#  38.497119999999995: 'e',
#  38.592119999999994: 'k',
#  38.68712: 'u',
#  38.73212: 'l',
#  38.872119999999995: 'e:',
#  39.00712: 'U',
#  39.07212: '6',
#  39.13212: 's',
#  39.33212: '<p:>',
#  39.53712: '?',
#  39.622119999999995: 'a:',
#  39.71212: 't',
#  39.80712: 'r',
#  39.92212: 'a',
#  40.05212: 'ts',
#  40.18212: '6',
#  40.24212: 'm',
#  40.33212: 'o',
#  40.42212: 'n',
#  40.46712: 'p',
#  40.56212: 'r',
#  40.64712: 'e',
#  40.72212: 'm',
#  40.82212: 'j',
#  40.89712: 'e:',
#  40.96212: 'd',
#  41.03712: 'E',
#  41.15212: 's',
#  41.24212: 'I',
#  41.28212: 'n',
#  41.597120000000004: '<p:>',
#  41.907120000000006: 'm',
#  42.002120000000005: 'o',
#  42.09212: 'n',
#  42.13212: 'd',
#  42.19712: 'E',
#  42.30712: 's',
#  42.43212: 'I',
#  42.50712: 'n',
#  42.55712: 'n',
#  42.607119999999995: 'U',
#  42.67212: 'm',
#  42.762119999999996: 'e:',
#  42.847120000000004: 'r',
#  42.95212: 'o',
#  43.06712: '?',
#  43.14712: 'aI',
#  43.19212: 'n',
#  43.222120000000004: 's',
#  43.60212: '<p:>',
#  43.997119999999995: '?',
#  44.06712: 'I',
#  44.127120000000005: 'l',
#  44.222120000000004: 'e:',
#  44.34212: 't',
#  44.407120000000006: 'a:',
#  44.44712: 'I',
#  44.53212: 'k',
#  44.637119999999996: 'O',
#  44.722120000000004: 'm',
#  44.78712: '@',
#  44.847120000000004: 'k',
#  44.97712: 'a',
#  45.84212: '<p:>',
#  46.65712: 'dZ',
#  46.72712: 'aI',
#  46.79712: 'm',
#  46.88212: 'O',
#  46.94712: 'n',
#  46.98212: 't',
#  47.04212: 'r',
#  47.12712: 'e:',
#  47.19212: 'm',
#  47.24212: 'o',
#  47.28212: 'n',
#  47.372119999999995: 'S',
#  47.472120000000004: 'E',
#  47.512119999999996: 'f',
#  47.57212: 'd',
#  47.63212: '?',
#  47.67212: 'o:',
#  47.73712: 'OY',
#  47.79212: 'v',
#  47.842119999999994: 'r',
#  47.90712: '@',
#  47.97712: '?',
#  48.06212: 'aU',
#  48.137119999999996: 'k',
#  48.18212: 's',
#  48.21212: 'g',
#  48.24212: 'r',
#  48.29712: 'a',
#  48.35212: 'n',
#  48.39712: '@',
#  48.44712: 'p',
#  48.49212: 'E',
#  48.56212: '6',
#  48.69212: 'z',
#  48.81712: 'o',
#  48.877120000000005: 'm',
#  48.95712: 'n',
#  49.03212: '@',
#  49.06212: 'E',
#  49.09212: 't',
#  49.22712: '<p:>',
#  49.44212: 'j',
#  49.57212: 'e',
#  49.63212: 'l',
#  49.69212: 'OY',
#  49.77212: 'r',
#  49.862120000000004: 'aI',
#  49.93712: 'd',
#  49.987120000000004: 'e:',
#  50.05212: 'm',
#  50.13212: 'a',
#  50.18712: 'n',
#  50.222120000000004: 'd',
#  50.27712: 'e:',
#  50.40212: 's',
#  50.50212: 'I',
#  50.53212: 'm',
#  50.59212: 'o',
#  50.65212: 'n',
#  50.68212: 'd',
#  50.74212: 'E',
#  50.862120000000004: 's',
#  50.95212: 'I',
#  50.98212: 'n',
#  51.04712: 'l',
#  51.11712: 'OY',
#  51.16212: 'r',
#  51.247119999999995: 'f',
#  51.327119999999994: 'aI',
#  51.39712: 'z',
#  51.49212: 'aI',
#  51.55212: 't',
#  51.60212: 'p',
#  51.67712: 'OY',
#  51.86712: 'r',
#  52.69712: '<p:>',
#  53.40212: '?',
#  53.472120000000004: 'E',
#  53.53212: 'l',
#  53.56212: '@',
#  53.60212: 'm',
#  53.717119999999994: 'o:',
#  53.857119999999995: 'n',
#  53.92212: 't',
#  54.01712: 'r',
#  54.18212: 'e:',
#  54.28212: 'b',
#  54.31212: 'm',
#  54.34212: 'd',
#  54.377120000000005: 'u:',
#  54.637119999999996: '<p:>',
#  54.91712: 'p',
#  54.99712: 'u:',
#  55.07712: 'r',
#  55.17212: 'k',
#  55.24212: 'v',
#  55.31712: 'OY',
#  55.43212: 'U',
#  55.51712: 'n',
#  55.58712: 'k',
#  55.702119999999994: 'a',
#  55.80212: 'p',
#  55.877120000000005: 'o:',
#  55.97712: 'f',
#  56.04212: '@',
#  56.08212: 'r',
#  56.13212: 'E',
#  56.17212: 'I',
#  56.28212: 't',
#  56.43212: '?',
#  56.50212: 'I',
#  56.61712: 'l',
#  57.10212: '<p:>',
#  57.50212: 'p',
#  57.53712: 'OY',
#  57.57212: 'r',
#  57.72712: '<p:>',
#  57.90212: 'm',
#  57.99212: 'o',
#  58.06212: 'n',
#  58.09212: 'd',
#  58.14712: 'E',
#  58.247119999999995: 's',
#  58.347120000000004: 'I',
#  58.41712: 'n',
#  58.46212: 'n',
#  58.49212: 'E',
#  58.56212: 'r',
#  58.637119999999996: 'e:',
#  58.68712: 'p',
#  58.73212: 'r',
#  58.77712: 'e:',
#  58.85212: 'z',
#  58.95212: 'E',
#  59.08712: 'n',
#  59.20712: 't',
#  59.29212: 'aI',
#  59.35212: 't',
#  59.38212: 'p',
#  59.44212: 'a',
#  59.56212: 'S',
#  59.65212: 'n',
#  59.68212: 'k',
#  59.71212: 'a',
#  59.77212: 'p',
#  59.87212: 'o:',
#  60.12212: '<p:>',
#  60.392120000000006: '?',
#  60.502120000000005: 'I',
#  60.56212: 'l',
#  60.62712: 'r',
#  60.68712: 'e:',
#  60.74212: 'p',
#  60.79712: 'r',
#  60.84212: 'e:',
#  60.91212: 'z',
#  60.987120000000004: 'E',
#  61.03712: 'n',
#  61.08712: 't',
#  61.16212: 'aI',
#  61.222120000000004: 't',
#  61.27712: 'U',
#  61.33212: 'n',
#  61.40712: 'z',
#  61.487120000000004: 'E',
#  61.55212: '6',
#  61.61212: 'b',
#  61.65712: 'p',
#  61.72712: 'E',
#  61.78212: 'n',
#  61.82712: 'b',
#  61.92712: 'o',
#  62.08212: 'a',
#  62.22712: 'k',
#  62.31712: 'v',
#  62.387119999999996: 'aI',
#  62.44212: 'd',
#  62.52712: 'I',
#  62.61212: 'k',
#  62.68212: 'e:',
#  62.78212: 'r',
#  62.85212: 'a:',
#  62.91212: 'I',
#  62.99212: 't',
#  63.06212: 'U',
#  63.11712: 'n',
#  63.19712: 'e:',
#  63.262119999999996: 'l',
#  63.33712: 'e:',
#  63.41212: 'b',
#  63.52712: 'a',
#  63.64212: 'n',
#  63.967119999999994: '?',
#  64.45212000000001: '<p:>',
#  64.71212: 'dZ',
#  64.83212: 'aI',
#  64.90711999999999: 'a',
#  64.97211999999999: 'l',
#  65.01212: 'O',
#  65.09711999999999: '6',
#  65.18212: 'z',
#  65.21212: 's',
#  65.25712: 'd',
#  65.33712: '@',
#  65.44211999999999: 's',
#  65.53211999999999: 'I',
#  65.60212: 'n',
#  65.74212: 'e:',
#  65.87212: 'l',
#  65.91212: 'I',
#  65.94212: 'n',
#  65.97712: 't',
#  66.05212: 'e:',
#  66.12212: 'r',
#  66.21212: 'j',
#  66.30712: 'OY',
#  66.35712: 'r',
#  66.40711999999999: 'd',
#  66.44712: 'u:',
#  66.52712: 'z',
#  66.60712000000001: 'E',
#  66.65212: '6',
#  66.69212: 'b',
#  66.75212: 'p',
#  66.83712: 'E',
#  66.89212: 'n',
#  66.93212: 'b',
#  67.01712: 'o',
#  67.14712: 'a',
#  67.39712: '?',
#  67.62212: 'a',
#  67.72211999999999: 'f',
#  67.79712: 'i:',
#  67.85712000000001: 'n',
#  67.91712: 'k',
#  67.95212: 'v',
#  67.98212: 'E',
#  68.01212: 'l',
#  68.04212: 'E',
#  68.07212: 's',
#  68.10212: 'g',
#  68.14712: 'r',
#  68.22212: 'a',
#  68.28712: 'n',
#  68.32212: '@',
#  68.35212: 'p',
#  68.38712000000001: 'E',
#  68.44212: '6',
#  68.52212: 'z',
#  68.60212: 'o',
#  68.65212: 'm',
#  68.68212: 'n',
#  68.71712: '@',
#  68.75212: 'p',
#  68.78212: 'U',
#  68.83212: 'I',
#  68.89712: 's',
#  68.94212: 'n',
#  69.00212: 'k',
#  69.06712: 'O',
#  69.10712000000001: 'm',
#  69.15711999999999: 'p',
#  69.22211999999999: 'r',
#  69.32712000000001: '@',
#  69.43212: 'n',
#  69.48712: 'd',
#  69.52712: 'r',
#  69.59212: '@',
#  69.90711999999999: '<p:>',
#  70.20712: '?',
#  70.29212000000001: 'E',
#  70.36212: 'l',
#  70.44212: '@',
#  70.52712: 's',
#  70.62712: 'O',
#  70.72712: 'n',
#  70.82212: '<p:>',
#  70.93712: 't',
#  71.05712: 'o',
#  71.16712: 'u:',
#  71.27712: 'j',
#  71.43712: 'u:',
#  71.53212: '6',
#  71.56212: 's',
#  71.60712: 'b',
#  71.68212: '@',
#  71.75712: 'z',
#  71.84712: 'OY',
#  71.92712: 'n',
#  71.96212: 'd',
#  71.99712: 'E',
#  72.04212000000001: 'k',
#  72.08712: 's',
#  72.13212: 'p',
#  72.17712: 'l',
#  72.22712: 'i:',
#  72.30212: 'k',
#  72.38212: 'a',
#  72.46212: 'ts',
#  72.55712: 'j',
#  72.62711999999999: 'o:',
#  72.66212: 'n',
#  72.69212: 's',
#  73.12712: '<p:>',
#  73.59212: 'm',
#  73.68212: 'o',
#  73.74212: 'n',
#  73.77212: 'd',
#  73.83212: 'E',
#  73.94212: 's',
#  74.04712: 'I',
#  74.12212: 'n',
#  74.18212: 'n',
#  74.22212: 'U',
#  74.25212: 'm',
#  74.31712: 'e:',
#  74.40711999999999: 'r',
#  74.51712: 'o',
#  74.62212: 'ts',
#  74.68212: 'v',
#  74.75212: 'aI',
#  74.91212: '<p:>',
#  75.08212: 'e:',
#  75.19211999999999: 't',
#  75.26712: 'a:',
#  75.30212: 'I',
#  75.35712000000001: 'k',
#  75.42712: 'O',
#  75.47212: 'm',
#  75.52212: '@',
#  75.58212: '<p:>',
#  75.64212: 'k',
#  75.72212: 'a',
#  76.48212000000001: '<p:>',
#  77.22712: 'l',
#  77.28712: 'E',
#  77.33212: 's',
#  77.37212: 'g',
#  77.43712: 'r',
#  77.52712: 'a',
#  77.59711999999999: 'n',
#  77.64712: '@',
#  77.70212000000001: 'p',
#  77.75211999999999: 'E',
#  77.82212: '6',
#  77.92212: 'z',
#  78.02212: 'o',
#  78.08212: 'm',
#  78.11712: 'n',
#  78.15212: '@',
#  78.18712: 'm',
#  78.23212000000001: 'o:',
#  78.28712: 'n',
#  78.37212: 'k',
#  78.45712: 'O',
#  78.50212: 'n',
#  78.59212: 'z',
#  78.69712: 'aI',
#  78.76212000000001: 'l',
#  78.86212: 'e:',
#  78.95212000000001: 'd',
#  79.02212: 'e',
#  79.13212: 'l',
#  79.23212000000001: 'aI',
#  79.35712000000001: 's',
#  79.47211999999999: '6',
#  79.52712: 'd',
#  79.58712: 'e',
#  79.67212: 'k',
#  79.74212: 'O',
#  79.83212: 't',
#  79.99212: 'e:',
#  80.16712: 'l',
#  80.28712: 'E',
#  80.33212: 's',
#  80.36712: 'd',
#  80.44211999999999: 'E',
#  80.56212: 's',
#  80.64212: '?',
#  80.68212: 'I',
#  80.74212: 'n',
#  80.79212: 's',
#  80.82212: 'd',
#  80.85712000000001: 'e',
#  80.94212: 'z',
#  81.03211999999999: 'E',
#  81.09711999999999: '6',
#  81.15711999999999: 'b',
#  81.20712: 'p',
#  81.25212: 'E',
#  81.34712: 'n',
#  81.44212: 'b',
#  81.52712: 'O',
#  81.66712000000001: 'a',
#  81.82712000000001: '?',
#  81.96712: 'u:',
#  82.07212000000001: 'v',
#  82.23212000000001: '6',
#  82.35212: 't',
#  82.42712: '?',
#  82.51712: 'o:',
#  82.58212: 'U',
#  82.66212: 'f',
#  82.72212: 'E',
#  82.78712: '6',
#  82.85712000000001: 'm',
#  82.89712: '2:',
#  82.99212: 'e:',
#  83.08212: 's',
#  83.24212: '?',
#  83.40711999999999: 'E',
#  83.44212: 't',
#  83.47712: 'd',
#  83.51712: 'e',
#  83.58212: 'm',
#  83.65711999999999: 'I',
#  83.70212: 'n',
#  83.73712: 't',
#  83.79712: 'e:',
#  83.86212: 'r',
#  83.92712: 'E',
#  84.03711999999999: 's',
#  84.15212: '6',
#  84.26212: 'p',
#  84.34212: 'l',
#  84.38712: 'u:',
#  84.46712: 't',
#  84.57212000000001: 'o:',
#  84.64212: 't',
#  84.67712: 'a:',
#  84.72712: 'l',
#  84.82212: 'a',
#  84.90212: 'k',
#  84.95712: 'e:',
#  85.03211999999999: 'o',
#  85.11712: 'g',
#  85.19712: 'r',
#  85.27712: 'a',
#  85.39212: 'f',
#  85.53211999999999: 'i:',
#  85.70212000000001: '<p:>',
#  85.83712: '?',
#  85.89712: 'a:',
#  85.94211999999999: 'l',
#  85.98212: 'h',
#  86.04212: 'I',
#  86.12711999999999: 's',
#  86.20212000000001: 't',
#  86.35712000000001: 'o',
#  86.49712: 'i',
#  86.55212: 'r',
#  86.60712000000001: '@',
#  86.66712000000001: '?',
#  86.75712: 'aU',
#  86.84212: 'k',
#  86.90711999999999: 'E',
#  86.99712: 'l',
#  87.10712000000001: 'k',
#  87.18212: 'U',
#  87.32212: 'l',
#  87.54212: '?',
#  87.66212: 'E',
#  87.69212: 't',
#  87.74712: 'a:',
#  87.82712000000001: 'l',
#  87.91712: 'a',
#  87.99712: 'k',
#  88.04712: 'r',
#  88.10712000000001: 'a',
#  88.21212: 'm',
#  88.38212: 'a:',
#  88.53211999999999: 'r',
#  88.59212: '@',
#  89.10712: '<p:>',
#  89.67712: 'ts',
#  89.76712: 'E',
#  89.80212: 's',
#  89.85212: 't',
#  89.93712: 'a',
#  90.00212: 'n',
#  90.09212: 'z',
#  90.24212: 'i',
#  90.35212: 'k',
#  90.40212: 'v',
#  90.44211999999999: 'E',
#  90.51712: 'dZ',
#  90.62711999999999: 'aI',
#  90.70712: 'a',
#  90.74212: 'p',
#  90.77212: '?',
#  90.83212: 'a:',
#  90.89712: 'n',
#  90.94211999999999: 'd',
#  90.98712: 'O',
#  91.04712: 'n',
#  91.16712: 'e:',
#  91.39212: '?',
#  91.57212: 'a:',
#  91.64212: 'l',
#  91.74212: 'a:',
#  91.82212: 'g',
#  91.85712000000001: '@',
#  91.94212: 'd',
#  92.03211999999999: 'e',
#  92.17212: 'z',
#  92.35212: 'I',
#  92.43212: 'k',
#  92.46212: 's',
#  92.53211999999999: 'a',
#  92.60212: 'n',
#  92.63212: 's',
#  92.83212: '<p:>',
#  93.03212: '?',
#  93.06712: 'U',
#  93.14712: 'n',
#  93.25712: '@',
#  93.41212: 'm',
#  93.58712: 'a:',
#  93.67212: 'g',
#  93.72211999999999: 'n',
#  93.80212: 'i',
#  93.92212: 'f',
#  94.04712: 'i',
#  94.11212: 'k',
#  94.14212: 'v',
#  94.17212: '@',
#  94.22211999999999: 'k',
#  94.28211999999999: 'a',
#  94.32212: 'r',
#  94.35212: 'r',
#  94.40212: 'i:',
#  94.45212: 'r',
#  94.51712: '@',
#  94.59212: 'd',
#  94.65711999999999: 'e',
#  94.75211999999999: 'p',
#  94.87711999999999: 'aI',
#  94.96712: 'n',
#  95.00712: 't',
#  95.09711999999999: 'r',
#  95.19211999999999: '@',
#  95.52712: '<p:>',
#  95.88712: 'j',
#  95.98212: 'a',
#  96.05712: 'v',
#  96.12711999999999: 'aI',
#  96.19211999999999: 's',
#  96.28211999999999: 'e:',
#  96.37212: 't',
#  96.45712: 'e:',
#  96.60212: 'd',
#  96.74712: 'e:',
#  96.84212: 'k',
#  96.94212: 'u:',
#  97.04212: 'r',
#  ...}

# %%
# Explore the TextGrid file, and add the voiced information

# Now that all the text grids are generated, it is needed to add to each Text Grid the 
# Following information: is it a voiced or a non-voiced phoneme?

# Voiced phonemes are the following:
voiced = ['Z','z','v','R','D','d','b']

# All the other phonemecs are then non-voiced

dict_ts_to_voiced = {}

for key in dict_ts_to_phoneme:
    if dict_ts_to_phoneme[key] in voiced:
        dict_ts_to_voiced[key] = 'voiced'
    else:
        dict_ts_to_voiced[key] = 'non-voiced'

# %%
dict_ts_to_voiced
# Out:
# {1.04356: 'non-voiced',
#  2.12712: 'non-voiced',
#  2.2221200000000003: 'non-voiced',
#  2.2921199999999997: 'non-voiced',
#  2.32212: 'voiced',
#  2.35712: 'non-voiced',
#  2.40712: 'non-voiced',
#  2.45212: 'voiced',
#  2.49712: 'non-voiced',
#  2.54712: 'non-voiced',
#  2.62712: 'non-voiced',
#  2.70212: 'voiced',
#  2.7671200000000002: 'non-voiced',
#  2.90712: 'non-voiced',
#  3.01712: 'voiced',
#  3.11712: 'non-voiced',
#  3.21212: 'non-voiced',
#  3.24212: 'non-voiced',
#  3.33712: 'non-voiced',
#  3.4571199999999997: 'non-voiced',
#  3.51212: 'non-voiced',
#  3.58712: 'non-voiced',
#  3.87712: 'non-voiced',
#  4.2121200000000005: 'non-voiced',
#  4.33212: 'non-voiced',
#  4.372120000000001: 'non-voiced',
#  4.417120000000001: 'non-voiced',
#  4.48212: 'non-voiced',
#  4.557119999999999: 'non-voiced',
#  4.6321200000000005: 'non-voiced',
#  4.72712: 'non-voiced',
#  4.8371200000000005: 'non-voiced',
#  4.91212: 'non-voiced',
#  5.06212: 'non-voiced',
#  5.23212: 'non-voiced',
#  5.28712: 'non-voiced',
#  5.35712: 'non-voiced',
#  5.4621200000000005: 'non-voiced',
#  5.61712: 'non-voiced',
#  5.77712: 'non-voiced',
#  5.85712: 'non-voiced',
#  5.897119999999999: 'non-voiced',
#  5.96212: 'non-voiced',
#  6.067119999999999: 'non-voiced',
#  6.15712: 'non-voiced',
#  6.22212: 'non-voiced',
#  6.28712: 'voiced',
#  6.36212: 'non-voiced',
#  6.432119999999999: 'non-voiced',
#  6.53212: 'non-voiced',
#  6.64712: 'non-voiced',
#  6.73212: 'non-voiced',
#  6.86712: 'non-voiced',
#  7.00212: 'voiced',
#  7.07212: 'non-voiced',
#  7.15212: 'non-voiced',
#  7.22212: 'non-voiced',
#  7.25212: 'non-voiced',
#  7.35712: 'non-voiced',
#  7.4671199999999995: 'non-voiced',
#  7.54712: 'non-voiced',
#  7.622120000000001: 'voiced',
#  7.67212: 'non-voiced',
#  7.72212: 'non-voiced',
#  7.76712: 'non-voiced',
#  7.87712: 'non-voiced',
#  8.01212: 'non-voiced',
#  8.11712: 'non-voiced',
#  8.22212: 'non-voiced',
#  8.29712: 'non-voiced',
#  8.36212: 'non-voiced',
#  8.42212: 'non-voiced',
#  8.45212: 'non-voiced',
#  8.517119999999998: 'non-voiced',
#  8.61712: 'non-voiced',
#  8.74212: 'non-voiced',
#  8.83212: 'non-voiced',
#  8.86212: 'non-voiced',
#  8.932120000000001: 'non-voiced',
#  9.01212: 'voiced',
#  9.057120000000001: 'non-voiced',
#  9.13212: 'voiced',
#  9.247119999999999: 'non-voiced',
#  9.34212: 'non-voiced',
#  9.397120000000001: 'non-voiced',
#  9.46212: 'non-voiced',
#  9.56212: 'non-voiced',
#  9.63712: 'non-voiced',
#  9.69212: 'non-voiced',
#  9.81712: 'non-voiced',
#  9.96212: 'non-voiced',
#  10.06212: 'non-voiced',
#  10.147120000000001: 'non-voiced',
#  10.247119999999999: 'non-voiced',
#  10.32712: 'non-voiced',
#  10.36212: 'non-voiced',
#  10.407119999999999: 'non-voiced',
#  10.45712: 'voiced',
#  10.54212: 'non-voiced',
#  10.67712: 'non-voiced',
#  10.787120000000002: 'non-voiced',
#  10.842120000000001: 'non-voiced',
#  11.337119999999999: 'non-voiced',
#  11.83212: 'non-voiced',
#  11.88712: 'non-voiced',
#  11.96212: 'non-voiced',
#  12.01712: 'non-voiced',
#  12.06712: 'non-voiced',
#  12.13712: 'non-voiced',
#  12.20712: 'non-voiced',
#  12.29212: 'voiced',
#  12.377120000000001: 'non-voiced',
#  12.43712: 'non-voiced',
#  12.51212: 'non-voiced',
#  12.59212: 'non-voiced',
#  12.682120000000001: 'non-voiced',
#  12.752120000000001: 'non-voiced',
#  12.82712: 'voiced',
#  12.907119999999999: 'non-voiced',
#  12.97212: 'non-voiced',
#  13.03712: 'voiced',
#  13.10212: 'non-voiced',
#  13.18712: 'non-voiced',
#  13.25212: 'non-voiced',
#  13.30212: 'voiced',
#  13.39212: 'non-voiced',
#  13.532119999999999: 'non-voiced',
#  13.712119999999999: 'non-voiced',
#  13.86212: 'non-voiced',
#  13.96212: 'voiced',
#  14.03712: 'non-voiced',
#  14.09712: 'non-voiced',
#  14.16712: 'voiced',
#  14.22712: 'non-voiced',
#  14.28712: 'non-voiced',
#  14.372119999999999: 'non-voiced',
#  14.467120000000001: 'non-voiced',
#  14.57212: 'non-voiced',
#  14.65212: 'non-voiced',
#  14.74212: 'non-voiced',
#  14.927119999999999: 'non-voiced',
#  15.08212: 'voiced',
#  15.17212: 'non-voiced',
#  15.52712: 'non-voiced',
#  15.88712: 'voiced',
#  16.002119999999998: 'non-voiced',
#  16.08712: 'non-voiced',
#  16.15712: 'non-voiced',
#  16.232120000000002: 'non-voiced',
#  16.29212: 'non-voiced',
#  16.387120000000003: 'non-voiced',
#  16.49212: 'non-voiced',
#  16.567120000000003: 'non-voiced',
#  16.65712: 'non-voiced',
#  16.762120000000003: 'voiced',
#  16.84212: 'non-voiced',
#  16.90712: 'voiced',
#  16.97712: 'non-voiced',
#  17.08712: 'non-voiced',
#  17.19212: 'non-voiced',
#  17.24212: 'non-voiced',
#  17.88712: 'non-voiced',
#  18.54712: 'non-voiced',
#  18.627119999999998: 'non-voiced',
#  18.69212: 'non-voiced',
#  18.72212: 'voiced',
#  18.79212: 'non-voiced',
#  18.89212: 'voiced',
#  18.98712: 'non-voiced',
#  19.05712: 'voiced',
#  19.122120000000002: 'non-voiced',
#  19.28212: 'non-voiced',
#  19.502119999999998: 'non-voiced',
#  19.65712: 'non-voiced',
#  19.737119999999997: 'non-voiced',
#  19.807119999999998: 'non-voiced',
#  19.86212: 'non-voiced',
#  19.96712: 'non-voiced',
#  20.10212: 'non-voiced',
#  20.192120000000003: 'non-voiced',
#  20.27712: 'non-voiced',
#  20.33712: 'voiced',
#  20.39212: 'non-voiced',
#  20.45712: 'non-voiced',
#  20.50712: 'voiced',
#  20.552120000000002: 'non-voiced',
#  20.60212: 'non-voiced',
#  20.692120000000003: 'non-voiced',
#  20.79212: 'voiced',
#  20.89712: 'non-voiced',
#  21.02212: 'non-voiced',
#  21.15712: 'non-voiced',
#  21.317120000000003: 'non-voiced',
#  21.42212: 'voiced',
#  21.512120000000003: 'non-voiced',
#  21.59212: 'non-voiced',
#  21.62212: 'non-voiced',
#  21.69212: 'non-voiced',
#  21.76212: 'non-voiced',
#  21.802120000000002: 'non-voiced',
#  21.872120000000002: 'non-voiced',
#  21.96212: 'non-voiced',
#  22.057119999999998: 'non-voiced',
#  22.19212: 'non-voiced',
#  22.29712: 'non-voiced',
#  22.39212: 'non-voiced',
#  22.512120000000003: 'non-voiced',
#  22.57712: 'non-voiced',
#  22.61212: 'non-voiced',
#  22.64212: 'non-voiced',
#  22.697119999999998: 'non-voiced',
#  22.75712: 'non-voiced',
#  22.79212: 'non-voiced',
#  22.83212: 'non-voiced',
#  22.92712: 'non-voiced',
#  23.06212: 'non-voiced',
#  23.184614500000002: 'non-voiced',
#  23.274603499999998: 'voiced',
#  23.347109: 'non-voiced',
#  23.40212: 'non-voiced',
#  23.49212: 'non-voiced',
#  23.58212: 'non-voiced',
#  23.63212: 'non-voiced',
#  23.68212: 'non-voiced',
#  23.72212: 'non-voiced',
#  23.76212: 'non-voiced',
#  23.84712: 'non-voiced',
#  23.96712: 'non-voiced',
#  24.03212: 'non-voiced',
#  24.122120000000002: 'voiced',
#  24.22712: 'non-voiced',
#  24.29712: 'non-voiced',
#  24.362119999999997: 'non-voiced',
#  24.57712: 'non-voiced',
#  24.84212: 'non-voiced',
#  24.93212: 'non-voiced',
#  24.99212: 'non-voiced',
#  25.10212: 'non-voiced',
#  25.20212: 'non-voiced',
#  25.27712: 'non-voiced',
#  25.38712: 'non-voiced',
#  25.482120000000002: 'non-voiced',
#  25.52212: 'voiced',
#  25.567120000000003: 'non-voiced',
#  25.61712: 'non-voiced',
#  25.67212: 'non-voiced',
#  25.737119999999997: 'non-voiced',
#  25.78212: 'non-voiced',
#  25.81212: 'non-voiced',
#  25.877119999999998: 'non-voiced',
#  25.96212: 'voiced',
#  26.06212: 'non-voiced',
#  26.18212: 'non-voiced',
#  26.31212: 'non-voiced',
#  26.41712: 'non-voiced',
#  26.50212: 'non-voiced',
#  26.57712: 'non-voiced',
#  26.66712: 'non-voiced',
#  26.762120000000003: 'non-voiced',
#  26.87712: 'non-voiced',
#  27.00712: 'non-voiced',
#  27.06212: 'non-voiced',
#  27.127119999999998: 'voiced',
#  27.19212: 'non-voiced',
#  27.307119999999998: 'non-voiced',
#  27.427120000000002: 'non-voiced',
#  27.46712: 'non-voiced',
#  27.50712: 'non-voiced',
#  27.54212: 'non-voiced',
#  27.58712: 'non-voiced',
#  27.65212: 'non-voiced',
#  27.70212: 'non-voiced',
#  27.732120000000002: 'non-voiced',
#  27.78712: 'non-voiced',
#  27.85212: 'non-voiced',
#  27.91212: 'non-voiced',
#  27.96712: 'non-voiced',
#  28.072119999999998: 'non-voiced',
#  28.177120000000002: 'voiced',
#  28.23712: 'non-voiced',
#  28.29212: 'non-voiced',
#  28.322119999999998: 'non-voiced',
#  28.38212: 'non-voiced',
#  28.49212: 'non-voiced',
#  28.572119999999998: 'non-voiced',
#  28.627119999999998: 'voiced',
#  28.71712: 'non-voiced',
#  28.78212: 'non-voiced',
#  28.81712: 'non-voiced',
#  28.857120000000002: 'non-voiced',
#  28.89212: 'voiced',
#  28.927120000000002: 'non-voiced',
#  29.02212: 'non-voiced',
#  29.13212: 'non-voiced',
#  29.197119999999998: 'non-voiced',
#  29.26212: 'non-voiced',
#  29.34212: 'non-voiced',
#  29.447119999999998: 'non-voiced',
#  30.38212: 'non-voiced',
#  31.317120000000003: 'non-voiced',
#  31.40712: 'non-voiced',
#  31.502119999999998: 'non-voiced',
#  31.59712: 'non-voiced',
#  31.65212: 'non-voiced',
#  31.732120000000002: 'non-voiced',
#  31.802120000000002: 'voiced',
#  31.83212: 'non-voiced',
#  31.86212: 'voiced',
#  31.957120000000003: 'non-voiced',
#  32.05212: 'non-voiced',
#  32.14712: 'non-voiced',
#  32.29712: 'non-voiced',
#  32.43712: 'non-voiced',
#  32.52212: 'non-voiced',
#  32.55712: 'non-voiced',
#  32.63212: 'non-voiced',
#  32.70212: 'non-voiced',
#  32.767120000000006: 'non-voiced',
#  32.85212: 'non-voiced',
#  32.96212: 'non-voiced',
#  33.10212: 'non-voiced',
#  33.19712: 'voiced',
#  33.28712: 'non-voiced',
#  33.40212: 'non-voiced',
#  33.472120000000004: 'non-voiced',
#  33.50212: 'non-voiced',
#  33.56712: 'non-voiced',
#  33.63212: 'non-voiced',
#  33.67712: 'non-voiced',
#  33.722120000000004: 'voiced',
#  33.75212: 'non-voiced',
#  33.78212: 'non-voiced',
#  33.872119999999995: 'non-voiced',
#  33.967119999999994: 'non-voiced',
#  34.00212: 'non-voiced',
#  34.03212: 'non-voiced',
#  34.08712: 'voiced',
#  34.17712: 'non-voiced',
#  34.262119999999996: 'non-voiced',
#  34.31212: 'non-voiced',
#  34.362120000000004: 'voiced',
#  34.502120000000005: 'non-voiced',
#  34.637119999999996: 'non-voiced',
#  34.71212: 'non-voiced',
#  34.78712: 'non-voiced',
#  35.00712: 'non-voiced',
#  35.24212: 'non-voiced',
#  35.362120000000004: 'non-voiced',
#  35.472120000000004: 'non-voiced',
#  35.54712: 'non-voiced',
#  35.64712: 'non-voiced',
#  35.752120000000005: 'non-voiced',
#  35.82212: 'non-voiced',
#  35.90712: 'non-voiced',
#  35.98212: 'non-voiced',
#  36.02712: 'non-voiced',
#  36.16212: 'non-voiced',
#  36.28212: 'non-voiced',
#  36.32212: 'non-voiced',
#  36.44712: 'non-voiced',
#  36.637119999999996: 'non-voiced',
#  36.75212: 'non-voiced',
#  36.80712: 'non-voiced',
#  36.92212: 'non-voiced',
#  37.02212: 'non-voiced',
#  37.13212: 'non-voiced',
#  37.30212: 'non-voiced',
#  37.46212: 'non-voiced',
#  37.58712: 'non-voiced',
#  37.66712: 'non-voiced',
#  37.72712: 'voiced',
#  37.782120000000006: 'non-voiced',
#  37.86712: 'non-voiced',
#  37.94712: 'non-voiced',
#  38.00712: 'non-voiced',
#  38.10212: 'non-voiced',
#  38.22212: 'non-voiced',
#  38.30712: 'non-voiced',
#  38.357119999999995: 'non-voiced',
#  38.39212: 'non-voiced',
#  38.44212: 'voiced',
#  38.497119999999995: 'non-voiced',
#  38.592119999999994: 'non-voiced',
#  38.68712: 'non-voiced',
#  38.73212: 'non-voiced',
#  38.872119999999995: 'non-voiced',
#  39.00712: 'non-voiced',
#  39.07212: 'non-voiced',
#  39.13212: 'non-voiced',
#  39.33212: 'non-voiced',
#  39.53712: 'non-voiced',
#  39.622119999999995: 'non-voiced',
#  39.71212: 'non-voiced',
#  39.80712: 'non-voiced',
#  39.92212: 'non-voiced',
#  40.05212: 'non-voiced',
#  40.18212: 'non-voiced',
#  40.24212: 'non-voiced',
#  40.33212: 'non-voiced',
#  40.42212: 'non-voiced',
#  40.46712: 'non-voiced',
#  40.56212: 'non-voiced',
#  40.64712: 'non-voiced',
#  40.72212: 'non-voiced',
#  40.82212: 'non-voiced',
#  40.89712: 'non-voiced',
#  40.96212: 'voiced',
#  41.03712: 'non-voiced',
#  41.15212: 'non-voiced',
#  41.24212: 'non-voiced',
#  41.28212: 'non-voiced',
#  41.597120000000004: 'non-voiced',
#  41.907120000000006: 'non-voiced',
#  42.002120000000005: 'non-voiced',
#  42.09212: 'non-voiced',
#  42.13212: 'voiced',
#  42.19712: 'non-voiced',
#  42.30712: 'non-voiced',
#  42.43212: 'non-voiced',
#  42.50712: 'non-voiced',
#  42.55712: 'non-voiced',
#  42.607119999999995: 'non-voiced',
#  42.67212: 'non-voiced',
#  42.762119999999996: 'non-voiced',
#  42.847120000000004: 'non-voiced',
#  42.95212: 'non-voiced',
#  43.06712: 'non-voiced',
#  43.14712: 'non-voiced',
#  43.19212: 'non-voiced',
#  43.222120000000004: 'non-voiced',
#  43.60212: 'non-voiced',
#  43.997119999999995: 'non-voiced',
#  44.06712: 'non-voiced',
#  44.127120000000005: 'non-voiced',
#  44.222120000000004: 'non-voiced',
#  44.34212: 'non-voiced',
#  44.407120000000006: 'non-voiced',
#  44.44712: 'non-voiced',
#  44.53212: 'non-voiced',
#  44.637119999999996: 'non-voiced',
#  44.722120000000004: 'non-voiced',
#  44.78712: 'non-voiced',
#  44.847120000000004: 'non-voiced',
#  44.97712: 'non-voiced',
#  45.84212: 'non-voiced',
#  46.65712: 'non-voiced',
#  46.72712: 'non-voiced',
#  46.79712: 'non-voiced',
#  46.88212: 'non-voiced',
#  46.94712: 'non-voiced',
#  46.98212: 'non-voiced',
#  47.04212: 'non-voiced',
#  47.12712: 'non-voiced',
#  47.19212: 'non-voiced',
#  47.24212: 'non-voiced',
#  47.28212: 'non-voiced',
#  47.372119999999995: 'non-voiced',
#  47.472120000000004: 'non-voiced',
#  47.512119999999996: 'non-voiced',
#  47.57212: 'voiced',
#  47.63212: 'non-voiced',
#  47.67212: 'non-voiced',
#  47.73712: 'non-voiced',
#  47.79212: 'voiced',
#  47.842119999999994: 'non-voiced',
#  47.90712: 'non-voiced',
#  47.97712: 'non-voiced',
#  48.06212: 'non-voiced',
#  48.137119999999996: 'non-voiced',
#  48.18212: 'non-voiced',
#  48.21212: 'non-voiced',
#  48.24212: 'non-voiced',
#  48.29712: 'non-voiced',
#  48.35212: 'non-voiced',
#  48.39712: 'non-voiced',
#  48.44712: 'non-voiced',
#  48.49212: 'non-voiced',
#  48.56212: 'non-voiced',
#  48.69212: 'voiced',
#  48.81712: 'non-voiced',
#  48.877120000000005: 'non-voiced',
#  48.95712: 'non-voiced',
#  49.03212: 'non-voiced',
#  49.06212: 'non-voiced',
#  49.09212: 'non-voiced',
#  49.22712: 'non-voiced',
#  49.44212: 'non-voiced',
#  49.57212: 'non-voiced',
#  49.63212: 'non-voiced',
#  49.69212: 'non-voiced',
#  49.77212: 'non-voiced',
#  49.862120000000004: 'non-voiced',
#  49.93712: 'voiced',
#  49.987120000000004: 'non-voiced',
#  50.05212: 'non-voiced',
#  50.13212: 'non-voiced',
#  50.18712: 'non-voiced',
#  50.222120000000004: 'voiced',
#  50.27712: 'non-voiced',
#  50.40212: 'non-voiced',
#  50.50212: 'non-voiced',
#  50.53212: 'non-voiced',
#  50.59212: 'non-voiced',
#  50.65212: 'non-voiced',
#  50.68212: 'voiced',
#  50.74212: 'non-voiced',
#  50.862120000000004: 'non-voiced',
#  50.95212: 'non-voiced',
#  50.98212: 'non-voiced',
#  51.04712: 'non-voiced',
#  51.11712: 'non-voiced',
#  51.16212: 'non-voiced',
#  51.247119999999995: 'non-voiced',
#  51.327119999999994: 'non-voiced',
#  51.39712: 'voiced',
#  51.49212: 'non-voiced',
#  51.55212: 'non-voiced',
#  51.60212: 'non-voiced',
#  51.67712: 'non-voiced',
#  51.86712: 'non-voiced',
#  52.69712: 'non-voiced',
#  53.40212: 'non-voiced',
#  53.472120000000004: 'non-voiced',
#  53.53212: 'non-voiced',
#  53.56212: 'non-voiced',
#  53.60212: 'non-voiced',
#  53.717119999999994: 'non-voiced',
#  53.857119999999995: 'non-voiced',
#  53.92212: 'non-voiced',
#  54.01712: 'non-voiced',
#  54.18212: 'non-voiced',
#  54.28212: 'voiced',
#  54.31212: 'non-voiced',
#  54.34212: 'voiced',
#  54.377120000000005: 'non-voiced',
#  54.637119999999996: 'non-voiced',
#  54.91712: 'non-voiced',
#  54.99712: 'non-voiced',
#  55.07712: 'non-voiced',
#  55.17212: 'non-voiced',
#  55.24212: 'voiced',
#  55.31712: 'non-voiced',
#  55.43212: 'non-voiced',
#  55.51712: 'non-voiced',
#  55.58712: 'non-voiced',
#  55.702119999999994: 'non-voiced',
#  55.80212: 'non-voiced',
#  55.877120000000005: 'non-voiced',
#  55.97712: 'non-voiced',
#  56.04212: 'non-voiced',
#  56.08212: 'non-voiced',
#  56.13212: 'non-voiced',
#  56.17212: 'non-voiced',
#  56.28212: 'non-voiced',
#  56.43212: 'non-voiced',
#  56.50212: 'non-voiced',
#  56.61712: 'non-voiced',
#  57.10212: 'non-voiced',
#  57.50212: 'non-voiced',
#  57.53712: 'non-voiced',
#  57.57212: 'non-voiced',
#  57.72712: 'non-voiced',
#  57.90212: 'non-voiced',
#  57.99212: 'non-voiced',
#  58.06212: 'non-voiced',
#  58.09212: 'voiced',
#  58.14712: 'non-voiced',
#  58.247119999999995: 'non-voiced',
#  58.347120000000004: 'non-voiced',
#  58.41712: 'non-voiced',
#  58.46212: 'non-voiced',
#  58.49212: 'non-voiced',
#  58.56212: 'non-voiced',
#  58.637119999999996: 'non-voiced',
#  58.68712: 'non-voiced',
#  58.73212: 'non-voiced',
#  58.77712: 'non-voiced',
#  58.85212: 'voiced',
#  58.95212: 'non-voiced',
#  59.08712: 'non-voiced',
#  59.20712: 'non-voiced',
#  59.29212: 'non-voiced',
#  59.35212: 'non-voiced',
#  59.38212: 'non-voiced',
#  59.44212: 'non-voiced',
#  59.56212: 'non-voiced',
#  59.65212: 'non-voiced',
#  59.68212: 'non-voiced',
#  59.71212: 'non-voiced',
#  59.77212: 'non-voiced',
#  59.87212: 'non-voiced',
#  60.12212: 'non-voiced',
#  60.392120000000006: 'non-voiced',
#  60.502120000000005: 'non-voiced',
#  60.56212: 'non-voiced',
#  60.62712: 'non-voiced',
#  60.68712: 'non-voiced',
#  60.74212: 'non-voiced',
#  60.79712: 'non-voiced',
#  60.84212: 'non-voiced',
#  60.91212: 'voiced',
#  60.987120000000004: 'non-voiced',
#  61.03712: 'non-voiced',
#  61.08712: 'non-voiced',
#  61.16212: 'non-voiced',
#  61.222120000000004: 'non-voiced',
#  61.27712: 'non-voiced',
#  61.33212: 'non-voiced',
#  61.40712: 'voiced',
#  61.487120000000004: 'non-voiced',
#  61.55212: 'non-voiced',
#  61.61212: 'voiced',
#  61.65712: 'non-voiced',
#  61.72712: 'non-voiced',
#  61.78212: 'non-voiced',
#  61.82712: 'voiced',
#  61.92712: 'non-voiced',
#  62.08212: 'non-voiced',
#  62.22712: 'non-voiced',
#  62.31712: 'voiced',
#  62.387119999999996: 'non-voiced',
#  62.44212: 'voiced',
#  62.52712: 'non-voiced',
#  62.61212: 'non-voiced',
#  62.68212: 'non-voiced',
#  62.78212: 'non-voiced',
#  62.85212: 'non-voiced',
#  62.91212: 'non-voiced',
#  62.99212: 'non-voiced',
#  63.06212: 'non-voiced',
#  63.11712: 'non-voiced',
#  63.19712: 'non-voiced',
#  63.262119999999996: 'non-voiced',
#  63.33712: 'non-voiced',
#  63.41212: 'voiced',
#  63.52712: 'non-voiced',
#  63.64212: 'non-voiced',
#  63.967119999999994: 'non-voiced',
#  64.45212000000001: 'non-voiced',
#  64.71212: 'non-voiced',
#  64.83212: 'non-voiced',
#  64.90711999999999: 'non-voiced',
#  64.97211999999999: 'non-voiced',
#  65.01212: 'non-voiced',
#  65.09711999999999: 'non-voiced',
#  65.18212: 'voiced',
#  65.21212: 'non-voiced',
#  65.25712: 'voiced',
#  65.33712: 'non-voiced',
#  65.44211999999999: 'non-voiced',
#  65.53211999999999: 'non-voiced',
#  65.60212: 'non-voiced',
#  65.74212: 'non-voiced',
#  65.87212: 'non-voiced',
#  65.91212: 'non-voiced',
#  65.94212: 'non-voiced',
#  65.97712: 'non-voiced',
#  66.05212: 'non-voiced',
#  66.12212: 'non-voiced',
#  66.21212: 'non-voiced',
#  66.30712: 'non-voiced',
#  66.35712: 'non-voiced',
#  66.40711999999999: 'voiced',
#  66.44712: 'non-voiced',
#  66.52712: 'voiced',
#  66.60712000000001: 'non-voiced',
#  66.65212: 'non-voiced',
#  66.69212: 'voiced',
#  66.75212: 'non-voiced',
#  66.83712: 'non-voiced',
#  66.89212: 'non-voiced',
#  66.93212: 'voiced',
#  67.01712: 'non-voiced',
#  67.14712: 'non-voiced',
#  67.39712: 'non-voiced',
#  67.62212: 'non-voiced',
#  67.72211999999999: 'non-voiced',
#  67.79712: 'non-voiced',
#  67.85712000000001: 'non-voiced',
#  67.91712: 'non-voiced',
#  67.95212: 'voiced',
#  67.98212: 'non-voiced',
#  68.01212: 'non-voiced',
#  68.04212: 'non-voiced',
#  68.07212: 'non-voiced',
#  68.10212: 'non-voiced',
#  68.14712: 'non-voiced',
#  68.22212: 'non-voiced',
#  68.28712: 'non-voiced',
#  68.32212: 'non-voiced',
#  68.35212: 'non-voiced',
#  68.38712000000001: 'non-voiced',
#  68.44212: 'non-voiced',
#  68.52212: 'voiced',
#  68.60212: 'non-voiced',
#  68.65212: 'non-voiced',
#  68.68212: 'non-voiced',
#  68.71712: 'non-voiced',
#  68.75212: 'non-voiced',
#  68.78212: 'non-voiced',
#  68.83212: 'non-voiced',
#  68.89712: 'non-voiced',
#  68.94212: 'non-voiced',
#  69.00212: 'non-voiced',
#  69.06712: 'non-voiced',
#  69.10712000000001: 'non-voiced',
#  69.15711999999999: 'non-voiced',
#  69.22211999999999: 'non-voiced',
#  69.32712000000001: 'non-voiced',
#  69.43212: 'non-voiced',
#  69.48712: 'voiced',
#  69.52712: 'non-voiced',
#  69.59212: 'non-voiced',
#  69.90711999999999: 'non-voiced',
#  70.20712: 'non-voiced',
#  70.29212000000001: 'non-voiced',
#  70.36212: 'non-voiced',
#  70.44212: 'non-voiced',
#  70.52712: 'non-voiced',
#  70.62712: 'non-voiced',
#  70.72712: 'non-voiced',
#  70.82212: 'non-voiced',
#  70.93712: 'non-voiced',
#  71.05712: 'non-voiced',
#  71.16712: 'non-voiced',
#  71.27712: 'non-voiced',
#  71.43712: 'non-voiced',
#  71.53212: 'non-voiced',
#  71.56212: 'non-voiced',
#  71.60712: 'voiced',
#  71.68212: 'non-voiced',
#  71.75712: 'voiced',
#  71.84712: 'non-voiced',
#  71.92712: 'non-voiced',
#  71.96212: 'voiced',
#  71.99712: 'non-voiced',
#  72.04212000000001: 'non-voiced',
#  72.08712: 'non-voiced',
#  72.13212: 'non-voiced',
#  72.17712: 'non-voiced',
#  72.22712: 'non-voiced',
#  72.30212: 'non-voiced',
#  72.38212: 'non-voiced',
#  72.46212: 'non-voiced',
#  72.55712: 'non-voiced',
#  72.62711999999999: 'non-voiced',
#  72.66212: 'non-voiced',
#  72.69212: 'non-voiced',
#  73.12712: 'non-voiced',
#  73.59212: 'non-voiced',
#  73.68212: 'non-voiced',
#  73.74212: 'non-voiced',
#  73.77212: 'voiced',
#  73.83212: 'non-voiced',
#  73.94212: 'non-voiced',
#  74.04712: 'non-voiced',
#  74.12212: 'non-voiced',
#  74.18212: 'non-voiced',
#  74.22212: 'non-voiced',
#  74.25212: 'non-voiced',
#  74.31712: 'non-voiced',
#  74.40711999999999: 'non-voiced',
#  74.51712: 'non-voiced',
#  74.62212: 'non-voiced',
#  74.68212: 'voiced',
#  74.75212: 'non-voiced',
#  74.91212: 'non-voiced',
#  75.08212: 'non-voiced',
#  75.19211999999999: 'non-voiced',
#  75.26712: 'non-voiced',
#  75.30212: 'non-voiced',
#  75.35712000000001: 'non-voiced',
#  75.42712: 'non-voiced',
#  75.47212: 'non-voiced',
#  75.52212: 'non-voiced',
#  75.58212: 'non-voiced',
#  75.64212: 'non-voiced',
#  75.72212: 'non-voiced',
#  76.48212000000001: 'non-voiced',
#  77.22712: 'non-voiced',
#  77.28712: 'non-voiced',
#  77.33212: 'non-voiced',
#  77.37212: 'non-voiced',
#  77.43712: 'non-voiced',
#  77.52712: 'non-voiced',
#  77.59711999999999: 'non-voiced',
#  77.64712: 'non-voiced',
#  77.70212000000001: 'non-voiced',
#  77.75211999999999: 'non-voiced',
#  77.82212: 'non-voiced',
#  77.92212: 'voiced',
#  78.02212: 'non-voiced',
#  78.08212: 'non-voiced',
#  78.11712: 'non-voiced',
#  78.15212: 'non-voiced',
#  78.18712: 'non-voiced',
#  78.23212000000001: 'non-voiced',
#  78.28712: 'non-voiced',
#  78.37212: 'non-voiced',
#  78.45712: 'non-voiced',
#  78.50212: 'non-voiced',
#  78.59212: 'voiced',
#  78.69712: 'non-voiced',
#  78.76212000000001: 'non-voiced',
#  78.86212: 'non-voiced',
#  78.95212000000001: 'voiced',
#  79.02212: 'non-voiced',
#  79.13212: 'non-voiced',
#  79.23212000000001: 'non-voiced',
#  79.35712000000001: 'non-voiced',
#  79.47211999999999: 'non-voiced',
#  79.52712: 'voiced',
#  79.58712: 'non-voiced',
#  79.67212: 'non-voiced',
#  79.74212: 'non-voiced',
#  79.83212: 'non-voiced',
#  79.99212: 'non-voiced',
#  80.16712: 'non-voiced',
#  80.28712: 'non-voiced',
#  80.33212: 'non-voiced',
#  80.36712: 'voiced',
#  80.44211999999999: 'non-voiced',
#  80.56212: 'non-voiced',
#  80.64212: 'non-voiced',
#  80.68212: 'non-voiced',
#  80.74212: 'non-voiced',
#  80.79212: 'non-voiced',
#  80.82212: 'voiced',
#  80.85712000000001: 'non-voiced',
#  80.94212: 'voiced',
#  81.03211999999999: 'non-voiced',
#  81.09711999999999: 'non-voiced',
#  81.15711999999999: 'voiced',
#  81.20712: 'non-voiced',
#  81.25212: 'non-voiced',
#  81.34712: 'non-voiced',
#  81.44212: 'voiced',
#  81.52712: 'non-voiced',
#  81.66712000000001: 'non-voiced',
#  81.82712000000001: 'non-voiced',
#  81.96712: 'non-voiced',
#  82.07212000000001: 'voiced',
#  82.23212000000001: 'non-voiced',
#  82.35212: 'non-voiced',
#  82.42712: 'non-voiced',
#  82.51712: 'non-voiced',
#  82.58212: 'non-voiced',
#  82.66212: 'non-voiced',
#  82.72212: 'non-voiced',
#  82.78712: 'non-voiced',
#  82.85712000000001: 'non-voiced',
#  82.89712: 'non-voiced',
#  82.99212: 'non-voiced',
#  83.08212: 'non-voiced',
#  83.24212: 'non-voiced',
#  83.40711999999999: 'non-voiced',
#  83.44212: 'non-voiced',
#  83.47712: 'voiced',
#  83.51712: 'non-voiced',
#  83.58212: 'non-voiced',
#  83.65711999999999: 'non-voiced',
#  83.70212: 'non-voiced',
#  83.73712: 'non-voiced',
#  83.79712: 'non-voiced',
#  83.86212: 'non-voiced',
#  83.92712: 'non-voiced',
#  84.03711999999999: 'non-voiced',
#  84.15212: 'non-voiced',
#  84.26212: 'non-voiced',
#  84.34212: 'non-voiced',
#  84.38712: 'non-voiced',
#  84.46712: 'non-voiced',
#  84.57212000000001: 'non-voiced',
#  84.64212: 'non-voiced',
#  84.67712: 'non-voiced',
#  84.72712: 'non-voiced',
#  84.82212: 'non-voiced',
#  84.90212: 'non-voiced',
#  84.95712: 'non-voiced',
#  85.03211999999999: 'non-voiced',
#  85.11712: 'non-voiced',
#  85.19712: 'non-voiced',
#  85.27712: 'non-voiced',
#  85.39212: 'non-voiced',
#  85.53211999999999: 'non-voiced',
#  85.70212000000001: 'non-voiced',
#  85.83712: 'non-voiced',
#  85.89712: 'non-voiced',
#  85.94211999999999: 'non-voiced',
#  85.98212: 'non-voiced',
#  86.04212: 'non-voiced',
#  86.12711999999999: 'non-voiced',
#  86.20212000000001: 'non-voiced',
#  86.35712000000001: 'non-voiced',
#  86.49712: 'non-voiced',
#  86.55212: 'non-voiced',
#  86.60712000000001: 'non-voiced',
#  86.66712000000001: 'non-voiced',
#  86.75712: 'non-voiced',
#  86.84212: 'non-voiced',
#  86.90711999999999: 'non-voiced',
#  86.99712: 'non-voiced',
#  87.10712000000001: 'non-voiced',
#  87.18212: 'non-voiced',
#  87.32212: 'non-voiced',
#  87.54212: 'non-voiced',
#  87.66212: 'non-voiced',
#  87.69212: 'non-voiced',
#  87.74712: 'non-voiced',
#  87.82712000000001: 'non-voiced',
#  87.91712: 'non-voiced',
#  87.99712: 'non-voiced',
#  88.04712: 'non-voiced',
#  88.10712000000001: 'non-voiced',
#  88.21212: 'non-voiced',
#  88.38212: 'non-voiced',
#  88.53211999999999: 'non-voiced',
#  88.59212: 'non-voiced',
#  89.10712: 'non-voiced',
#  89.67712: 'non-voiced',
#  89.76712: 'non-voiced',
#  89.80212: 'non-voiced',
#  89.85212: 'non-voiced',
#  89.93712: 'non-voiced',
#  90.00212: 'non-voiced',
#  90.09212: 'voiced',
#  90.24212: 'non-voiced',
#  90.35212: 'non-voiced',
#  90.40212: 'voiced',
#  90.44211999999999: 'non-voiced',
#  90.51712: 'non-voiced',
#  90.62711999999999: 'non-voiced',
#  90.70712: 'non-voiced',
#  90.74212: 'non-voiced',
#  90.77212: 'non-voiced',
#  90.83212: 'non-voiced',
#  90.89712: 'non-voiced',
#  90.94211999999999: 'voiced',
#  90.98712: 'non-voiced',
#  91.04712: 'non-voiced',
#  91.16712: 'non-voiced',
#  91.39212: 'non-voiced',
#  91.57212: 'non-voiced',
#  91.64212: 'non-voiced',
#  91.74212: 'non-voiced',
#  91.82212: 'non-voiced',
#  91.85712000000001: 'non-voiced',
#  91.94212: 'voiced',
#  92.03211999999999: 'non-voiced',
#  92.17212: 'voiced',
#  92.35212: 'non-voiced',
#  92.43212: 'non-voiced',
#  92.46212: 'non-voiced',
#  92.53211999999999: 'non-voiced',
#  92.60212: 'non-voiced',
#  92.63212: 'non-voiced',
#  92.83212: 'non-voiced',
#  93.03212: 'non-voiced',
#  93.06712: 'non-voiced',
#  93.14712: 'non-voiced',
#  93.25712: 'non-voiced',
#  93.41212: 'non-voiced',
#  93.58712: 'non-voiced',
#  93.67212: 'non-voiced',
#  93.72211999999999: 'non-voiced',
#  93.80212: 'non-voiced',
#  93.92212: 'non-voiced',
#  94.04712: 'non-voiced',
#  94.11212: 'non-voiced',
#  94.14212: 'voiced',
#  94.17212: 'non-voiced',
#  94.22211999999999: 'non-voiced',
#  94.28211999999999: 'non-voiced',
#  94.32212: 'non-voiced',
#  94.35212: 'non-voiced',
#  94.40212: 'non-voiced',
#  94.45212: 'non-voiced',
#  94.51712: 'non-voiced',
#  94.59212: 'voiced',
#  94.65711999999999: 'non-voiced',
#  94.75211999999999: 'non-voiced',
#  94.87711999999999: 'non-voiced',
#  94.96712: 'non-voiced',
#  95.00712: 'non-voiced',
#  95.09711999999999: 'non-voiced',
#  95.19211999999999: 'non-voiced',
#  95.52712: 'non-voiced',
#  95.88712: 'non-voiced',
#  95.98212: 'non-voiced',
#  96.05712: 'voiced',
#  96.12711999999999: 'non-voiced',
#  96.19211999999999: 'non-voiced',
#  96.28211999999999: 'non-voiced',
#  96.37212: 'non-voiced',
#  96.45712: 'non-voiced',
#  96.60212: 'voiced',
#  96.74712: 'non-voiced',
#  96.84212: 'non-voiced',
#  96.94212: 'non-voiced',
#  97.04212: 'non-voiced',
#  ...}

# %%
# Now load the MEG recording, and add this information as annotations
TASK = 'rest'

subject = '220628'

path_bids = '/home/co/workspace_LPP/data/MEG/LPP/LPP_bids'


bids_path = mne_bids.BIDSPath(
            subject=subject,
            session='01',
            task=TASK,
            datatype="meg",
            root=path_bids,
            run='01',
        )

raw = mne_bids.read_raw_bids(bids_path)
# Out:
# Opening raw data file /home/co/workspace_LPP/data/MEG/LPP/LPP_bids/sub-220628/ses-01/meg/sub-220628_ses-01_task-rest_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 23000 ... 649999 =     23.000 ...   649.999 secs
# Ready.
# Reading events from /home/co/workspace_LPP/data/MEG/LPP/LPP_bids/sub-220628/ses-01/meg/sub-220628_ses-01_task-rest_run-01_events.tsv.
# Reading channel info from /home/co/workspace_LPP/data/MEG/LPP/LPP_bids/sub-220628/ses-01/meg/sub-220628_ses-01_task-rest_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# <ipython-input-32-a3bf1f277060>:18: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# <ipython-input-32-a3bf1f277060>:18: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)

# %%
events_path = str(bids_path.fpath)[:-7] + 'events_base.tsv'

# %%
events = pd.read_csv(events_path,delimiter = '\t')[['onset','duration','trial_type']]

# %%
events

# Now we have to:

# Align the phonemes timestamps with the current onset of words as in the events.tsv file

# Add them as a kind: phoneme
# Out:
#        onset  duration                           trial_type
# 0       3.05      0.37  {'kind': 'word', 'word': 'lorsque'}
# 1       3.42      0.02        {'kind': 'word', 'word': 'j'}
# 2       3.53      0.23    {'kind': 'word', 'word': 'avais'}
# 3       3.93      0.25      {'kind': 'word', 'word': 'six'}
# 4       4.18      0.18      {'kind': 'word', 'word': 'ans'}
# ...      ...       ...                                  ...
# 1627  609.51      0.14     {'kind': 'word', 'word': 'peut'}
# 1628  609.65      0.22      {'kind': 'word', 'word': 'pas'}
# 1629  609.87      0.17    {'kind': 'word', 'word': 'aller'}
# 1630  610.04      0.16     {'kind': 'word', 'word': 'bien'}
# 1631  610.20      0.18     {'kind': 'word', 'word': 'loin'}
#
# [1632 rows x 3 columns]

# %%
long_events = events.onset[1631] - events.onset[0]
long_events
# Out:
# 607.1500000000001

# %%
long_ph = list(dict_ts_to_voiced.keys())[-1] -  list(dict_ts_to_voiced.keys())[0]
long_ph
# Out:
# 610.0059070000001

# %%
# First phoneme is incorrect

del dict_ts_to_voiced[1.04356]

# %%
# There is an offset between the first word and the first phoneme: let's reajust

offset = events.onset[0] - list(dict_ts_to_voiced.keys())[0]

print(f'Offset is : {offset}')
# Out:
# Offset is : 0.9228799999999997

# %%
for timestamp in dict_ts_to_voiced.keys():
    timestamp_final = timestamp + offset 
    to_add = pd.DataFrame([timestamp_final, 0.02, {'kind':'phoneme','voice':dict_ts_to_voiced[timestamp]}])
    to_add_t = to_add.transpose()
    to_add_t.columns = events.columns
    events = pd.concat([events, to_add_t])
    
events
# Out:
#          onset duration                                  trial_type
# 0         3.05     0.37         {'kind': 'word', 'word': 'lorsque'}
# 1         3.42     0.02               {'kind': 'word', 'word': 'j'}
# 2         3.53     0.23           {'kind': 'word', 'word': 'avais'}
# 3         3.93     0.25             {'kind': 'word', 'word': 'six'}
# 4         4.18     0.18             {'kind': 'word', 'word': 'ans'}
# ..         ...      ...                                         ...
# 0      610.295     0.02  {'kind': 'phoneme', 'voice': 'non-voiced'}
# 0      610.345     0.02  {'kind': 'phoneme', 'voice': 'non-voiced'}
# 0       610.38     0.02  {'kind': 'phoneme', 'voice': 'non-voiced'}
# 0      610.415     0.02  {'kind': 'phoneme', 'voice': 'non-voiced'}
# 0   611.972347     0.02  {'kind': 'phoneme', 'voice': 'non-voiced'}
#
# [7861 rows x 3 columns]

# %%
events.to_csv(str(bids_path.fpath)[:-7] + 'events.tsv', sep='\t',index=False)
