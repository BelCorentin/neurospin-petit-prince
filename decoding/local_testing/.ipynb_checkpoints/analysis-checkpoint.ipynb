# %% [markdown]
# # Analysis and plotting Notebook

# %% [markdown]
# ### TODO
#
# Investigate why the auditory analysis crashes
#
# Do a second decoding job for the word only, depending on whether the word is the last word of a constituent or not

# %%
from dataset import analysis

analysis(modality = "auditory", decoding_criterion = "embeddings")
# Out:
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 3
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-3/ses-01/meg/sub-3_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 28000 ... 658999 =     28.000 ...   658.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-3/ses-01/meg/sub-3_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-3/ses-01/meg/sub-3_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1954 events found
# Event IDs: [  1 129]
# Boom subject 3
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 4
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-4/ses-01/meg/sub-4_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 40000 ... 665999 =     40.000 ...   665.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-4/ses-01/meg/sub-4_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-4/ses-01/meg/sub-4_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 4
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 5
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-5/ses-01/meg/sub-5_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#     Range : 25000 ... 642999 =     25.000 ...   642.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-5/ses-01/meg/sub-5_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-5/ses-01/meg/sub-5_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1709 events found
# Event IDs: [  1 128]
# Boom subject 5
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 6
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-6/ses-01/meg/sub-6_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 38000 ... 654999 =     38.000 ...   654.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-6/ses-01/meg/sub-6_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-6/ses-01/meg/sub-6_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 6
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 7
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-7/ses-01/meg/sub-7_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 170000 ... 791999 =    170.000 ...   791.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-7/ses-01/meg/sub-7_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-7/ses-01/meg/sub-7_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 7
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 8
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-8/ses-01/meg/sub-8_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 23000 ... 649999 =     23.000 ...   649.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-8/ses-01/meg/sub-8_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-8/ses-01/meg/sub-8_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 8
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 9
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-9/ses-01/meg/sub-9_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 70000 ... 694999 =     70.000 ...   694.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-9/ses-01/meg/sub-9_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-9/ses-01/meg/sub-9_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 9
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 10
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-10/ses-01/meg/sub-10_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 18000 ... 648999 =     18.000 ...   648.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-10/ses-01/meg/sub-10_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-10/ses-01/meg/sub-10_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 10
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 11
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-11/ses-01/meg/sub-11_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 70000 ... 774999 =     70.000 ...   774.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-11/ses-01/meg/sub-11_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-11/ses-01/meg/sub-11_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# Trigger channel has a non-zero initial value of 4 (consider using initial_event=True to detect this event)
# 1646 events found
# Event IDs: [  1  63 128]
# Boom subject 11
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 12
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-12/ses-01/meg/sub-12_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 10000 ... 627999 =     10.000 ...   627.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-12/ses-01/meg/sub-12_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-12/ses-01/meg/sub-12_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1716 events found
# Event IDs: [  1 128]
# Boom subject 12
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 13
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-13/ses-01/meg/sub-13_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 271000 ... 893999 =    271.000 ...   893.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-13/ses-01/meg/sub-13_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-13/ses-01/meg/sub-13_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 13
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 14
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-14/ses-01/meg/sub-14_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 509000 ... 1129999 =    509.000 ...  1129.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-14/ses-01/meg/sub-14_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-14/ses-01/meg/sub-14_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 14
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 15
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-15/ses-01/meg/sub-15_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 251000 ... 879999 =    251.000 ...   879.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-15/ses-01/meg/sub-15_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-15/ses-01/meg/sub-15_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 15
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 16
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-16/ses-01/meg/sub-16_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 148000 ... 785999 =    148.000 ...   785.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-16/ses-01/meg/sub-16_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-16/ses-01/meg/sub-16_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 16
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 17
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-17/ses-01/meg/sub-17_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 106000 ... 780999 =    106.000 ...   780.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-17/ses-01/meg/sub-17_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-17/ses-01/meg/sub-17_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 17
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 18
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-18/ses-01/meg/sub-18_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#     Range : 13000 ... 640999 =     13.000 ...   640.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-18/ses-01/meg/sub-18_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-18/ses-01/meg/sub-18_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1703 events found
# Event IDs: [  1 128]
# Boom subject 18
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 19
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-19/ses-01/meg/sub-19_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 91000 ... 714999 =     91.000 ...   714.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-19/ses-01/meg/sub-19_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-19/ses-01/meg/sub-19_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 19
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 20
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-20/ses-01/meg/sub-20_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 142000 ... 774999 =    142.000 ...   774.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-20/ses-01/meg/sub-20_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-20/ses-01/meg/sub-20_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 20
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 21
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-21/ses-01/meg/sub-21_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 101000 ... 722999 =    101.000 ...   722.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-21/ses-01/meg/sub-21_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-21/ses-01/meg/sub-21_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 129 131]
# Boom subject 21
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 22
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-22/ses-01/meg/sub-22_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 51000 ... 735999 =     51.000 ...   735.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-22/ses-01/meg/sub-22_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-22/ses-01/meg/sub-22_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 22
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 23
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-23/ses-01/meg/sub-23_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#     Range : 110000 ... 727999 =    110.000 ...   727.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-23/ses-01/meg/sub-23_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-23/ses-01/meg/sub-23_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 2 events found
# Event IDs: [1]
# Boom subject 23
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 24
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-24/ses-01/meg/sub-24_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 76000 ... 695999 =     76.000 ...   695.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-24/ses-01/meg/sub-24_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-24/ses-01/meg/sub-24_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 2150 events found
# Event IDs: [  1 128]
# Boom subject 24
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 25
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-25/ses-01/meg/sub-25_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 72000 ... 691999 =     72.000 ...   691.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-25/ses-01/meg/sub-25_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-25/ses-01/meg/sub-25_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# ...
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 51
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 52
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-52/ses-01/meg/sub-52_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 34000 ... 650999 =     34.000 ...   650.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-52/ses-01/meg/sub-52_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-52/ses-01/meg/sub-52_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 52
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 53
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-53/ses-01/meg/sub-53_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 52000 ... 669999 =     52.000 ...   669.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-53/ses-01/meg/sub-53_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-53/ses-01/meg/sub-53_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 1616 events found
# Event IDs: [  1 128]
# Boom subject 53
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 54
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-54/ses-01/meg/sub-54_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 102000 ... 728999 =    102.000 ...   728.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-54/ses-01/meg/sub-54_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-54/ses-01/meg/sub-54_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# Trigger channel has a non-zero initial value of 2048 (consider using initial_event=True to detect this event)
# 1616 events found
# Event IDs: [2049 2176]
# Boom subject 54
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 55
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-55/ses-01/meg/sub-55_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 7000 ... 626999 =      7.000 ...   626.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-55/ses-01/meg/sub-55_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-55/ses-01/meg/sub-55_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# Trigger channel has a non-zero initial value of 5 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 2978 events found
# Event IDs: [  1 128]
# Boom subject 55
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 56
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-56/ses-01/meg/sub-56_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 15000 ... 634999 =     15.000 ...   634.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-56/ses-01/meg/sub-56_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-56/ses-01/meg/sub-56_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 2989 events found
# Event IDs: [  1 128]
# Boom subject 56
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 57
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-57/ses-01/meg/sub-57_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 29000 ... 650999 =     29.000 ...   650.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-57/ses-01/meg/sub-57_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-57/ses-01/meg/sub-57_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 2966 events found
# Event IDs: [  1 128]
# Boom subject 57
# Reading raw files for modality: auditory
#
#  Epoching for run 1, subject: 58
#
# Opening raw data file /home/is153802/data/LPP_MEG_auditory/sub-58/ses-01/meg/sub-58_ses-01_task-listen_run-01_meg.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 35000 ... 653999 =     35.000 ...   653.999 secs
# Ready.
# Reading events from /home/is153802/data/LPP_MEG_auditory/sub-58/ses-01/meg/sub-58_ses-01_task-listen_run-01_events.tsv.
# Reading channel info from /home/is153802/data/LPP_MEG_auditory/sub-58/ses-01/meg/sub-58_ses-01_task-listen_run-01_channels.tsv.
# Using 4 HPI coils: 293 307 314 321 Hz
# Not fully anonymizing info - keeping his_id, sex, and hand info
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /mnt/localdrive/workspace-LPP/code/neurospin-petit-prince/decoding/local_testing/dataset.py:65: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)
# 2981 events found
# Event IDs: [  1 128]
# Boom subject 58

# %%
modality = 'visual'; decoding = 'embeddings'
# load_scores('visual','embeddings')
plot_scores(modality, decoding)
