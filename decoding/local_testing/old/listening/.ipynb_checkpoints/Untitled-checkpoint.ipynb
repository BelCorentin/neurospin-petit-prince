# %%
from check_decoding import *

# %%
PATHS.data = Path('/home/is153802/workspace_LPP/data/MEG/LPP/BIDS_lecture')

# %%
bids_path = mne_bids.BIDSPath(
            subject='1',
            session="01",
            task='listen',
            datatype="meg",
            root=PATHS.data,
            run='01',
        )

# %%
run_id = '01'
raw = mne_bids.read_raw_bids(bids_path)
raw.pick_types(meg=True, stim=True)
raw.load_data()
raw = raw.filter(0.5, 20)

event_file = PATHS.data / f"sub-{bids_path.subject}"
event_file = event_file / f"ses-{bids_path.session}"
event_file = event_file / "meg"
event_file = str(event_file / f"sub-{bids_path.subject}")
event_file += f"_ses-{bids_path.session}"
event_file += f"_task-{bids_path.task}"
event_file += f"_run-{bids_path.run}_events.tsv"
assert Path(event_file).exists()
# read events
meta = pd.read_csv(event_file, sep="\t")
events = mne.find_events(
    raw, stim_channel="STI101", shortest_event=1, min_duration=0.0010001
)
# Out:
# /tmp/ipykernel_1846648/144404254.py:2: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne_bids.read_raw_bids(bids_path)
# /tmp/ipykernel_1846648/144404254.py:2: RuntimeWarning: Omitted 4 annotation(s) that were outside data range.
#   raw = mne_bids.read_raw_bids(bids_path)
# /tmp/ipykernel_1846648/144404254.py:2: RuntimeWarning: The unit for channel(s) STI001, STI002, STI003, STI004, STI005, STI006, STI007, STI008, STI009, STI010, STI011, STI012, STI013, STI014, STI015, STI016, STI101, STI201, STI301 has changed from V to NA.
#   raw = mne_bids.read_raw_bids(bids_path)

# %%
word_length_meg = events[:,2]
word_length_meta = meta.word.apply(len)
i,j = match_list(word_len_meta,word_length_meg)

# %%
run_id = '01'
print(f"Len i : {len(i)} for run {run_id}")
assert len(i) > 500
events = events[i]
# events = events[i]  # events = words_events[i]
meta = meta.iloc[j].reset_index()

meta['start'] = events[:,0]/raw.info['sfreq']
# Out:
# Len i : 1411 for run 01

# %%
epochs = mne.Epochs(
    raw, events, metadata=meta, tmin=-0.1, tmax=0.6, decim=20, baseline=(-0.1, 0.0)
)
# Out:
# /tmp/ipykernel_1846648/1721045210.py:1: RuntimeWarning: The measurement information indicates a low-pass frequency of 20.0 Hz. The decim=20 parameter will result in a sampling frequency of 50.0 Hz, which can cause aliasing artifacts.
#   epochs = mne.Epochs(

# %%
epochs.load_data()
epochs = epochs.pick_types(meg=True,stim=False,misc=False)

# %%
def decod(X, y):
    assert len(X) == len(y)
    # define data
    model = make_pipeline(StandardScaler(), RidgeCV(alphas=np.logspace(-3, 8, 10)))
    cv = KFold(15, shuffle=True, random_state=0)

    # fit predict
    n, n_chans, n_times = X.shape
    if y.ndim == 1:
        y = np.asarray(y).reshape(y.shape[0],1)
    R = np.zeros((n_times, y.shape[1]))
    
    for t in range(n_times):
        print(".", end="")
        rs = []
        # y_pred = cross_val_predict(model, X[:, :, t], y, cv=cv)
        for train, test in cv.split(X):
            model.fit(X[train,:,t],y[train])
            y_pred = model.predict(X[test,:,t])
            r = correlate(y[test],y_pred)
            rs.append(r)
        R[t] = np.mean(rs)    
        #R[t] = correlate(y, y_pred)
        
    return R

# %%
X = epochs.get_data()
y = epochs.metadata.word.apply(len)

# %%
R = decod(X,y)
# Out:
# ....................................

# %%
# %matplotlib inline

# %%
plt.fill_between(epochs.times,np.squeeze(R))

# %%
evoked = epochs.average(method='median')

# %%
evoked.plot()

# %%
epochs.metadata['trigger_value'] = epochs.events[:,2]

# %%
epochs.metadata.iloc[:40]
# Out:
#     index  Unnamed: 0          word  onset  duration  \
# 0       1           1       j'avais   1.05       0.3
# 1       2           2           six   1.40       0.3
# 2       3           3          ans,   1.75       0.3
# 3       4           4          j'ai   2.10       0.3
# 4       5           5           vu,   2.45       0.3
# 5       6           6           une   2.80       0.3
# 6       7           7         fois,   3.15       0.3
# 7       8           8           une   3.50       0.3
# 8       9           9    magnifique   3.85       0.3
# 9      10          10        image,   4.20       0.3
# 10     11          11          dans   4.55       0.3
# 11     12          12            un   4.90       0.3
# 12     13          13         livre   5.25       0.3
# 13     14          14           sur   5.60       0.3
# 14     15          15            la   5.95       0.3
# 15     16          16         forêt   6.30       0.3
# 16     17          17        vierge   6.65       0.3
# 17     18          18           qui   7.00       0.3
# 18     19          19    s'appelait   7.35       0.3
# 19     20          20     histoires   7.70       0.3
# 20     21          21       vécues.   8.05       0.3
# 21     22          22            Ça   8.40       0.3
# 22     23          23  représentait   8.75       0.3
# 23     24          24            un   9.10       0.3
# 24     25          25       serpent   9.45       0.3
# 25     26          26           boa   9.80       0.3
# 26     27          27           qui  10.15       0.3
# 27     28          28       avalait  10.50       0.3
# 28     29          29            un  10.85       0.3
# 29     30          30        fauve.  11.20       0.3
# 30     31          31         Voilà  11.55       0.3
# 31     32          32            la  11.90       0.3
# 32     33          33         copie  12.25       0.3
# 33     34          34            du  12.60       0.3
# 34     35          35       dessin.  12.95       0.3
# 35     36          36            On  13.30       0.3
# 36     37          37        disait  13.65       0.3
# 37     38          38          dans  14.00       0.3
# 38     39          39            le  14.35       0.3
# 39     40          40        livre:  14.70       0.3
#
#                                   trial_type   start
# 0         {'kind': 'word', 'word': 'javais'}  43.914
# 1            {'kind': 'word', 'word': 'six'}  44.534
# 2            {'kind': 'word', 'word': 'ans'}  44.889
# 3            {'kind': 'word', 'word': 'jai'}  45.189
# 4             {'kind': 'word', 'word': 'vu'}  45.489
# 5            {'kind': 'word', 'word': 'une'}  45.806
# 6           {'kind': 'word', 'word': 'fois'}  46.122
# 7            {'kind': 'word', 'word': 'une'}  46.439
# 8     {'kind': 'word', 'word': 'magnifique'}  46.756
# 9          {'kind': 'word', 'word': 'image'}  47.072
# 10          {'kind': 'word', 'word': 'dans'}  47.389
# 11            {'kind': 'word', 'word': 'un'}  47.706
# 12         {'kind': 'word', 'word': 'livre'}  48.022
# 13           {'kind': 'word', 'word': 'sur'}  48.339
# 14            {'kind': 'word', 'word': 'la'}  48.639
# 15         {'kind': 'word', 'word': 'forêt'}  48.956
# 16        {'kind': 'word', 'word': 'vierge'}  49.272
# 17           {'kind': 'word', 'word': 'qui'}  49.589
# 18     {'kind': 'word', 'word': 'sappelait'}  49.906
# 19     {'kind': 'word', 'word': 'histoires'}  50.222
# 20        {'kind': 'word', 'word': 'vécues'}  50.539
# 21            {'kind': 'word', 'word': 'Ça'}  50.856
# 22  {'kind': 'word', 'word': 'représentait'}  51.172
# 23            {'kind': 'word', 'word': 'un'}  51.644
# 24       {'kind': 'word', 'word': 'serpent'}  51.972
# 25           {'kind': 'word', 'word': 'boa'}  52.289
# 26           {'kind': 'word', 'word': 'qui'}  52.606
# 27       {'kind': 'word', 'word': 'avalait'}  52.922
# 28            {'kind': 'word', 'word': 'un'}  53.239
# 29         {'kind': 'word', 'word': 'fauve'}  53.556
# 30         {'kind': 'word', 'word': 'Voilà'}  53.872
# 31            {'kind': 'word', 'word': 'la'}  54.189
# 32         {'kind': 'word', 'word': 'copie'}  54.658
# 33            {'kind': 'word', 'word': 'du'}  54.989
# 34        {'kind': 'word', 'word': 'dessin'}  55.306
# 35            {'kind': 'word', 'word': 'On'}  55.622
# 36        {'kind': 'word', 'word': 'disait'}  55.939
# 37          {'kind': 'word', 'word': 'dans'}  56.413
# 38            {'kind': 'word', 'word': 'le'}  56.739
# 39         {'kind': 'word', 'word': 'livre'}  57.056
