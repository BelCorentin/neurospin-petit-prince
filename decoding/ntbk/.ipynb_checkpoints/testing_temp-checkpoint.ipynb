# %%
from decoding.functions.dataset import add_syntax
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from decoding.functions.dataset import add_syntax
#
# ModuleNotFoundError: No module named 'decoding'

# %%
from dataset import analysis_subject, get_subjects, get_path
import mne
mne.set_log_level(verbose='error')


# PB WITH SUB - 35 TO DEBUG RUN 5
modality = 'visual'
decoding_criterion = 'word'
level = 'sentence'
start = 'onset'
subject = '4'
path = get_path(modality)
scores = analysis_subject(subject,
    modality,
    start,
    level,
    decoding_criterion,
    runs=9)
# Out:
# Reading raw files for modality: visual
#
#  Epoching for run 1, subject: 4
# /home/co/miniconda3/envs/meg-masc/lib/python3.10/site-packages/pandas/core/series.py:893: RuntimeWarning: invalid value encountered in cast
#   return np.asarray(self._values, dtype)
# -1.0 1000.0
# <class 'float'> <class 'float'>
# -1000.0
# Reading raw files for modality: visual
#
#  Epoching for run 2, subject: 4
# /home/co/miniconda3/envs/meg-masc/lib/python3.10/site-packages/pandas/core/series.py:893: RuntimeWarning: invalid value encountered in cast
#   return np.asarray(self._values, dtype)
# -1.0 1000.0
# <class 'float'> <class 'float'>
# -1000.0
# Reading raw files for modality: visual
#
#  Epoching for run 3, subject: 4
# /home/co/miniconda3/envs/meg-masc/lib/python3.10/site-packages/pandas/core/series.py:893: RuntimeWarning: invalid value encountered in cast
#   return np.asarray(self._values, dtype)
# -1.0 1000.0
# <class 'float'> <class 'float'>
# -1000.0
# ...

# %%
from dataset import unique_plot
unique_plot(
    subject, level, start, decoding_criterion, modality, from_scores=True, scores=scores
)
