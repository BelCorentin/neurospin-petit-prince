# %% [markdown]
# # General stats about LPP's text
#
#
# ## Purpose
# Get an insight of the syntactic properties of the text.
#
#
# ## Suggested next steps
# State suggested next steps, based on results obtained in this notebook.

# %% [markdown]
# ### Sentence Length

# %%
#!pip install nltk
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached regex-2022.10.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (770 kB)
# ...

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /home/is153802/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/is153802/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
import numpy as np
import string

# %%
dict_i_chapt = {1: '1-3',2:'4-6',3:'7-9',4:'10-12',5:'13-14',6:'15:19',7:'20-22',8:'23-25',9:'26-27'}
sentence_arr = []
nb_words_sentence = []

for chap in np.arange(1,10):
    with open(f'./../../experiments/formatting/txt_raw/ch{dict_i_chapt[i]}.txt') as temp_file:
        lpp = temp_file.read()
        number_of_sentences = sent_tokenize(lpp)
        sentence_arr.append(len(number_of_sentences))
        for sentence in number_of_sentences:
            tokenized_text = nltk.word_tokenize(sentence)
            words=[word.lower() for word in tokenized_text if word.isalpha()]
            nb_words_sentence.append(len(words))

# %%
import matplotlib.pyplot as plt

h = nb_words_sentence
fig, ax = plt.subplots(figsize=(25, 15))
bins = np.arange(1,max(h) + 1.5) - 0.5
ax.hist(h,  bins, density=False)

for rect in ax.patches:
    height = rect.get_height()
    ax.annotate(f'{int(height)}', xy=(rect.get_x()+rect.get_width()/2, height), 
                xytext=(0, 5), textcoords='offset points', ha='center', va='bottom')
ax.set_xticks(bins+0.5)
plt.show()
