# %%
import os.path as op
import shutil

import mne
from mne_bids import (BIDSPath, write_raw_bids, read_raw_bids,
                      inspect_dataset, mark_channels)

# %%
raw2 = mne.io.read_raw_fif('/home/is153802/workspace_LPP/data/MEG/LPP/raw/fr_190151/190715/fr_r1_raw.fif')
# Out:
# Opening raw data file /home/is153802/workspace_LPP/data/MEG/LPP/raw/fr_190151/190715/fr_r1_raw.fif...
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 raw2 = mne.io.read_raw_fif('/home/is153802/workspace_LPP/data/MEG/LPP/raw/fr_190151/190715/fr_r1_raw.fif')
#
# File ~/.pyenv/versions/base/lib/python3.10/site-packages/mne/io/fiff/raw.py:482, in read_raw_fif(fname, allow_maxshield, preload, on_split_missing, verbose)
#     442 @fill_doc
#     443 def read_raw_fif(fname, allow_maxshield=False, preload=False,
#     444                  on_split_missing='raise', verbose=None):
#     445     """Reader function for Raw FIF data.
#     446
#     447     Parameters
#    (...)
#     480     are updated accordingly.
#     481     """
# --> 482     return Raw(fname=fname, allow_maxshield=allow_maxshield,
#     483                preload=preload, verbose=verbose,
#     484                on_split_missing=on_split_missing)
#
# File <decorator-gen-261>:12, in __init__(self, fname, allow_maxshield, preload, on_split_missing, verbose)
#
# File ~/.pyenv/versions/base/lib/python3.10/site-packages/mne/io/fiff/raw.py:81, in Raw.__init__(self, fname, allow_maxshield, preload, on_split_missing, verbose)
#      78 next_fname = fname
#      79 while next_fname is not None:
#      80     raw, next_fname, buffer_size_sec = \
# ---> 81         self._read_raw_file(next_fname, allow_maxshield,
#      82                             preload, do_check_ext)
#      83     do_check_ext = False
#      84     raws.append(raw)
#
# File <decorator-gen-262>:12, in _read_raw_file(self, fname, allow_maxshield, preload, do_check_ext, verbose)
#
# File ~/.pyenv/versions/base/lib/python3.10/site-packages/mne/io/fiff/raw.py:171, in Raw._read_raw_file(self, fname, allow_maxshield, preload, do_check_ext, verbose)
#     169 if (len(raw_node) == 0):
#     170     raise ValueError('No raw data in %s' % fname_rep)
# --> 171 _check_maxshield(allow_maxshield)
#     172 with info._unlock():
#     173     info['maxshield'] = True
#
# File ~/.pyenv/versions/base/lib/python3.10/site-packages/mne/io/base.py:2561, in _check_maxshield(allow_maxshield)
#    2558 else:
#    2559     msg += (' Use allow_maxshield=True if you are sure you'
#    2560             ' want to load the data despite this warning.')
# -> 2561     raise ValueError(msg)
#
# ValueError: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data. Use allow_maxshield=True if you are sure you want to load the data despite this warning.

# %%
raw_stat = mne.io.read_raw_fif('/home/is153802/workspace_LPP/data/MEG/LPP/alternative_bids/sub-180131/ses-0/meg/sub-180131_ses-0_task-0_run-01_meg.fif',allow_maxshield=True)
# Out:
# Opening raw data file /home/is153802/workspace_LPP/data/MEG/LPP/alternative_bids/sub-180131/ses-0/meg/sub-180131_ses-0_task-0_run-01_meg.fif...
# Isotrak not found
#     Read a total of 13 projection items:
#         grad_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v5 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v6 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v7 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-v8 (1 x 306)  idle
#     Range : 934000 ... 1575999 =    934.000 ...  1575.999 secs
# Ready.
# /tmp/ipykernel_239434/2212716414.py:1: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw_stat = mne.io.read_raw_fif('/home/is153802/workspace_LPP/data/MEG/LPP/alternative_bids/sub-180131/ses-0/meg/sub-180131_ses-0_task-0_run-01_meg.fif',allow_maxshield=True)

# %%
raw_stat.info
# Out:
# <Info | 21 non-empty values
#  acq_pars: ACQch001 110113 ACQch002 110112 ACQch003 110111 ACQch004 110122 ...
#  bads: []
#  ch_names: MEG0113, MEG0112, MEG0111, MEG0122, MEG0123, MEG0121, MEG0132, ...
#  chs: 204 Gradiometers, 102 Magnetometers, 5 Stimulus, 64 EEG, 17 misc
#  custom_ref_applied: False
#  description: MEG user (meg) Vectorview system
#  events: 1 item (list)
#  experimenter: Common
#  file_id: 4 items (dict)
#  highpass: 0.1 Hz
#  hpi_subsystem: 3 items (dict)
#  line_freq: 50.0
#  lowpass: 330.0 Hz
#  maxshield: True
#  meas_date: 2018-01-31 13:39:43 UTC
#  meas_id: 4 items (dict)
#  nchan: 392
#  proc_history: 1 item (list)
#  proj_id: 1 item (ndarray)
#  proj_name: petit_prince
#  projs: grad_ssp_upright.fif : PCA-v1: off, grad_ssp_upright.fif : ...
#  sfreq: 1000.0 Hz
#  subject_info: 6 items (dict)
# >

# %%
from mne.preprocessing import maxwell_filter
path_cal = '/home/is153802/workspace_LPP/data/MEG/LPP/MEG_cal_files/sss_cal_nsp_2017.dat'
raw_sss = maxwell_filter(raw_stat,calibration = path_cal)
# Out:
# Maxwell filtering raw data
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [10], in <cell line: 3>()
#       1 from mne.preprocessing import maxwell_filter
#       2 path_cal = '/home/is153802/workspace_LPP/data/MEG/LPP/MEG_cal_files/sss_cal_nsp_2017.dat'
# ----> 3 raw_sss = maxwell_filter(raw_stat,calibration = path_cal)
#
# File <decorator-gen-457>:12, in maxwell_filter(raw, origin, int_order, ext_order, calibration, cross_talk, st_duration, st_correlation, coord_frame, destination, regularize, ignore_ref, bad_condition, head_pos, st_fixed, st_only, mag_scale, skip_by_annotation, extended_proj, verbose)
#
# File ~/.pyenv/versions/base/lib/python3.10/site-packages/mne/preprocessing/maxwell.py:344, in maxwell_filter(raw, origin, int_order, ext_order, calibration, cross_talk, st_duration, st_correlation, coord_frame, destination, regularize, ignore_ref, bad_condition, head_pos, st_fixed, st_only, mag_scale, skip_by_annotation, extended_proj, verbose)
#     191 """Maxwell filter data using multipole moments.
#     192
#     193 Parameters
#    (...)
#     341 .. footbibliography::
#     342 """  # noqa: E501
#     343 logger.info('Maxwell filtering raw data')
# --> 344 params = _prep_maxwell_filter(
#     345     raw=raw, origin=origin, int_order=int_order, ext_order=ext_order,
#     346     calibration=calibration, cross_talk=cross_talk,
#     347     st_duration=st_duration, st_correlation=st_correlation,
#     348     coord_frame=coord_frame, destination=destination,
#     349     regularize=regularize, ignore_ref=ignore_ref,
#     350     bad_condition=bad_condition, head_pos=head_pos, st_fixed=st_fixed,
#     351     st_only=st_only, mag_scale=mag_scale,
#     352     skip_by_annotation=skip_by_annotation, extended_proj=extended_proj)
#     353 raw_sss = _run_maxwell_filter(raw, **params)
#     354 # Update info
#
# File <decorator-gen-458>:12, in _prep_maxwell_filter(raw, origin, int_order, ext_order, calibration, cross_talk, st_duration, st_correlation, coord_frame, destination, regularize, ignore_ref, bad_condition, head_pos, st_fixed, st_only, mag_scale, skip_by_annotation, extended_proj, reconstruct, verbose)
#
# File ~/.pyenv/versions/base/lib/python3.10/site-packages/mne/preprocessing/maxwell.py:397, in _prep_maxwell_filter(raw, origin, int_order, ext_order, calibration, cross_talk, st_duration, st_correlation, coord_frame, destination, regularize, ignore_ref, bad_condition, head_pos, st_fixed, st_only, mag_scale, skip_by_annotation, extended_proj, reconstruct, verbose)
#     394 _check_option('bad_condition', bad_condition,
#     395               ['error', 'warning', 'ignore', 'info'])
#     396 if raw.info['dev_head_t'] is None and coord_frame == 'head':
# --> 397     raise RuntimeError('coord_frame cannot be "head" because '
#     398                        'info["dev_head_t"] is None; if this is an '
#     399                        'empty room recording, consider using '
#     400                        'coord_frame="meg"')
#     401 if st_only and st_duration is None:
#     402     raise ValueError('st_duration must not be None if st_only is True')
#
# RuntimeError: coord_frame cannot be "head" because info["dev_head_t"] is None; if this is an empty room recording, consider using coord_frame="meg"

# %%
bids_root = '/home/is153802/workspace_LPP/data/MEG/LPP/LPP_bids'


# print_dir_tree(bids_root)

# print(make_report(bids_root))

datatype = 'meg'
session = '01'
run = '01'
task = 'rest'
suffix = 'meg'
subject = '220707'
bids_path = BIDSPath(root=bids_root, subject=subject,suffix = suffix, task=task,run=run,
                     session=session, datatype=datatype)
# Out:
# [BIDSPath(
# root: /home/is153802/workspace_LPP/data/MEG/LPP/LPP_bids
# datatype: meg
# basename: sub-220707_ses-01_task-rest_run-01_meg.fif)]
# /home/is153802/workspace_LPP/data/MEG/LPP/LPP_bids/sub-220707/ses-01/meg/sub-220707_ses-01_task-rest_run-01_meg.fif
# BIDSPath(
# root: /home/is153802/workspace_LPP/data/MEG/LPP/LPP_bids
# datatype: meg
# basename: sub-220707_ses-01_task-rest_run-01_meg)

# %%
# 
inspect_dataset(bids_path, l_freq=0.1, h_freq=30.)
# Out:
# Reading 0 ... 632999  =      0.000 ...   632.999 secs...
# Finding segments below or above PTP threshold.
# <MNEBrowseFigure size 800x800 with 5 Axes>

# %%
raw.plot()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 5 Axes>
# <MNEBrowseFigure size 800x800 with 5 Axes>

# %%
raw.plot_psd(average = True)
# Out:
# Effective window size : 2.048 (s)
# Effective window size : 2.048 (s)
# <MNELineFigure size 1000x600 with 2 Axes>
# <MNELineFigure size 1000x600 with 2 Axes>

# %%
raw.plot_projs_topomap(colorbar=True)
# Out:
# <MNEFigure size 975x731.5 with 26 Axes>
# <MNEFigure size 975x731.5 with 26 Axes>
