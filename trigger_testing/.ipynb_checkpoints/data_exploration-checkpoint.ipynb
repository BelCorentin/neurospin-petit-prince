# %%
import mne 

from mne_bids import read_raw_bids,print_dir_tree,make_report,BIDSPath
import matplotlib.pyplot as plt

# %%
bids_root = '/home/is153802/workspace_LPP/data/MEG/LPP/alternative_bids'


# print_dir_tree(bids_root)

# print(make_report(bids_root))

datatype = 'meg'
session = '0'
run = '01'
task = '0'
suffix = 'meg'
subject = '190715'
bids_path = BIDSPath(root=bids_root, subject=subject,suffix = suffix, task=task,run=run, session=session, datatype=datatype)

print(bids_path.match())
print(bids_path)
bids_path
# Out:
# []
# /home/is153802/workspace_LPP/data/MEG/LPP/alternative_bids/sub-190715/ses-01/meg/sub-190715_ses-01_task-0_run-01_meg
# BIDSPath(
# root: /home/is153802/workspace_LPP/data/MEG/LPP/alternative_bids
# datatype: meg
# basename: sub-190715_ses-01_task-0_run-01_meg)

# %%
# 
raw = read_raw_bids(bids_path=bids_path, verbose=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 #
# ----> 2 raw = read_raw_bids(bids_path=bids_path, verbose=False)
#
# File <decorator-gen-590>:10, in read_raw_bids(bids_path, extra_params, verbose)
#
# File ~/.pyenv/versions/base/lib/python3.10/site-packages/mne_bids/read.py:683, in read_raw_bids(bids_path, extra_params, verbose)
#     680             break
#     682 if not raw_path.exists():
# --> 683     raise FileNotFoundError(f'File does not exist: {raw_path}')
#     684 if config_path is not None and not config_path.exists():
#     685     raise FileNotFoundError(f'config directory not found: {config_path}')
#
# FileNotFoundError: File does not exist: /home/is153802/workspace_LPP/data/MEG/LPP/alternative_bids/sub-190715/ses-01/meg/sub-190715_ses-01_task-0_run-01_meg

# %%
raw.plot()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 5 Axes>
# <MNEBrowseFigure size 800x800 with 5 Axes>

# %%
raw.plot_psd(average = True)
# Out:
# Effective window size : 2.048 (s)
# Effective window size : 2.048 (s)
# <MNELineFigure size 1000x600 with 2 Axes>
# <MNELineFigure size 1000x600 with 2 Axes>

# %%
raw.plot_projs_topomap(colorbar=True)
# Out:
# <MNEFigure size 975x731.5 with 26 Axes>
# <MNEFigure size 975x731.5 with 26 Axes>
